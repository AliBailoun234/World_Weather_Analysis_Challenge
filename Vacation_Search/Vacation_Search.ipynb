# %% [markdown]
# # Deliverable 2. Create a Customer Travel Destinations Map.
# ----
# 1. Create a folder called `Vacation_Search` to save all the files related with this deliverable.
#
# 2. Download the `Vacation_Search_starter_code.ipynb` Jupyter notebook,save it into your `Vacation_Search folder`, and rename it as `Vacation_Search.ipynb`.
#
# 3. In the `Vacation_Search.ipynb` file, ensure that the dependencies and the Google API key is imported correctly.
#
# 4. From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame named `city_data_df`.
#
# 5. Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.
#
# 6. Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected. Name the DataFrame as `preferred_cities_df`.
#
# 7. Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.
#
# 8. Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".
#
# 9. Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.
#
# 10. Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.
#
# 11. Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.
#
# 12. Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.
#
# 13. Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.
#
# 14. Review the formatting template provided that you'll use to add an information box to each marker in the map. In the pop-up for each city you'll add:
#
#     1. The city name.
#
#     2. The country code.
#
#     3. The weather description and maximum temperature for the city.
#
# 15. Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.
#
# 16. Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.
#
# 17. Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.
#
# 18. Take a screenshot of your map and save it to the `Vacation_Search` folder as `WeatherPy_vacation_map.png`.
# ---

# %% [markdown]
# ## Ensure that the dependencies and the Google API key is imported correctly.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import Google API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %% [markdown]
# ## From the `Weather_Database` folder you created in the "Deliverable 1," import the `WeatherPy_Database.csv` file as a Pandas DataFrame.

# %%
# Set the file path to import the WeatherPy_database.csv file
file_path = "../Weather_Database/WeatherPy_database.csv"

# Load the CSV file into a Pandas DataFrame
city_data_df = pd.read_csv(file_path)

# Display sample data
city_data_df.head()
# Out:
#    City          City.1 Country      lat       lng  Max Temp  Humidity  \
# 0     0          Dikson      RU  73.5069   80.5464      5.67        95
# 1     1            Tura      IN  25.5198   90.2201     60.87        89
# 2     2         Rikitea      PF -23.1203 -134.9692     72.16        86
# 3     3  Severo-Kurilsk      RU  50.6789  156.1250     33.75        69
# 4     4      Chokurdakh      RU  70.6333  147.9167    -10.41        95
#
#    Cloudiness  Wind Speed Weather Description
# 0         100         NaN          light snow
# 1           0         NaN           clear sky
# 2         100         NaN          light rain
# 3         100         NaN     overcast clouds
# 4          99         NaN     overcast clouds

# %% [markdown]
# ## Write two input statements that prompt the user to enter their minimum and maximum temperature criteria for their vacation.

# %%
# Prompt the user to enter the minimum temperature criteria
min_temp = float(input("What is the minimum temperature criteria for your vacation?"))

# Prompt the user to enter the maximum temperature criteria
max_temp = float(input("What is the maximum temperature criteria for your vacation?"))
# Out:
# What is the minimum temperature criteria for your vacation?75
# What is the maximum temperature criteria for your vacation?90

# %% [markdown]
# ## Create a new Pandas DataFrame by using the `loc` Pandas method to filter the `city_data_df` DataFrame for temperature criteria  collected.

# %%
# Filter the city_data_df DataFrame to find the cities that fit the criteria using the loc Pandas function
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >=min_temp)]
                                    
# Display sample data
preferred_cities_df.head(11)
# Out:
#     City              City.1 Country      lat       lng  Max Temp  Humidity  \
# 13    13           Hithadhoo      MV  -0.6000   73.0833     81.07        74
# 14    14  Sao Felix Do Xingu      BR  -6.6447  -51.9950     82.20        67
# 17    17               Kapaa      US  22.0752 -159.3190     80.92        73
# 18    18     Delta Del Tigre      UY -34.7633  -56.3853     75.61        46
# 19    19          Butaritari      KI   3.0707  172.7902     80.71        74
# 26    26         Dicabisagan      PH  17.0818  122.4157     76.75        88
# 29    29              Lompoc      US  34.6391 -120.4579     75.78        30
# 31    31              Sorong      ID  -0.8833  131.2500     79.11        87
# 33    33                Hilo      US  19.7297 -155.0900     84.25        78
# 38    38            Victoria      HK  22.2855  114.1577     75.38        88
# 39    39           Namatanai      PG  -3.6667  152.4333     80.87        74
#
#     Cloudiness  Wind Speed Weather Description
# 13          64         NaN       broken clouds
# 14          94         NaN          light rain
# 17          40         NaN    scattered clouds
# 18          75         NaN       broken clouds
# 19          60         NaN       broken clouds
# 26          99         NaN       moderate rain
# 29           0         NaN           clear sky
# 31         100         NaN     overcast clouds
# 33          40         NaN    scattered clouds
# 38           0         NaN           clear sky
# 39         100         NaN     overcast clouds

# %% [markdown]
# ## Create a new Pandas DataFrame named `clean_travel_cities` by using the Pandas `dropna` function on the `preferred_cities_df` to drop any empty rows.

# %%
# Drop any empty rows in the preferred_cities_df DataFrame and create a new DataFrame.
clean_travel_cities = preferred_cities_df.dropna()

# Display sample data
clean_travel_cities.head(11)
# Out:
# Empty DataFrame
# Columns: [City, City.1, Country, lat, lng, Max Temp, Humidity, Cloudiness, Wind Speed, Weather Description]
# Index: []

# %% [markdown]
# ## Use the `copy` Pandas function to create a new DataFrame, called `hotel_df`, by copying the following columns from the `clean_travel_cities` DataFrame: "City", "Country", "Max Temp", "Current Description", "Lat", "Lng".

# %%
# Create DataFrame called hotel_df by copying some columns from the clean_travel_cities DataFrame.
hotel_df = preferred_cities_df[["City.1","Country","Max Temp","Weather Description","lat","lng"]].copy()
# hotel_df.drop(columns = ["City","Humidity","Cloudiness","Wind Speed"], inplace=True)

# Display sample data
hotel_df.head()
# Out:
#                 City.1 Country  Max Temp Weather Description      lat  \
# 13           Hithadhoo      MV     81.07       broken clouds  -0.6000
# 14  Sao Felix Do Xingu      BR     82.20          light rain  -6.6447
# 17               Kapaa      US     80.92    scattered clouds  22.0752
# 18     Delta Del Tigre      UY     75.61       broken clouds -34.7633
# 19          Butaritari      KI     80.71       broken clouds   3.0707
#
#          lng
# 13   73.0833
# 14  -51.9950
# 17 -159.3190
# 18  -56.3853
# 19  172.7902

# %% [markdown]
# ## Add a new empty column named `Hotel Name` to the `hotel_df` DataFrame.

# %%
# Add a new empty column, "Hotel Name", to the hotel_df DataFrame
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                 City.1 Country  Max Temp Weather Description      lat  \
# 13           Hithadhoo      MV     81.07       broken clouds  -0.6000
# 14  Sao Felix Do Xingu      BR     82.20          light rain  -6.6447
# 17               Kapaa      US     80.92    scattered clouds  22.0752
# 18     Delta Del Tigre      UY     75.61       broken clouds -34.7633
# 19          Butaritari      KI     80.71       broken clouds   3.0707
#
#          lng Hotel Name
# 13   73.0833
# 14  -51.9950
# 17 -159.3190
# 18  -56.3853
# 19  172.7902

# %% [markdown]
# ## Review the hotel search parameters provided. These parameters are the same we used in this module; you'll use them to search for a hotel for each city.

# %%
# Review the parameters to search for a hotel
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %% [markdown]
# ## Use a for loop to iterate through the `hotel_df` DataFrame, retrieve the latitude and longitude of each city to find the nearest hotel based on the search parameters provided, then add the hotel name to the `hotel_df` DataFrame. If a hotel isn't found, skip to the next city.

# %%
# Iterate through the hotel DataFrame 
for index, row in hotel_df.iterrows():
    # Fetch latitude and longitude from the DataFrame
    lat = row["lat"]
    lng = row["lng"]
    
    # Add the latitude and longitude as parameters to the params dictionary
    params["location"] = f"{lat},{lng}"
    
    # Set up the base URL for the Google Directions API to get JSON data
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # Make an API request and retrieve the JSON data from the hotel search
    hotels = requests.get(base_url, params=params).json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found skip the city
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
# Display sample data
hotel_df.head(10)
# Out:
#                 City.1 Country  Max Temp Weather Description      lat  \
# 13           Hithadhoo      MV     81.07       broken clouds  -0.6000
# 14  Sao Felix Do Xingu      BR     82.20          light rain  -6.6447
# 17               Kapaa      US     80.92    scattered clouds  22.0752
# 18     Delta Del Tigre      UY     75.61       broken clouds -34.7633
# 19          Butaritari      KI     80.71       broken clouds   3.0707
# 26         Dicabisagan      PH     76.75       moderate rain  17.0818
# 29              Lompoc      US     75.78           clear sky  34.6391
# 31              Sorong      ID     79.11     overcast clouds  -0.8833
# 33                Hilo      US     84.25    scattered clouds  19.7297
# 38            Victoria      HK     75.38           clear sky  22.2855
#
#          lng                                Hotel Name
# 13   73.0833                         Scoop Guest House
# 14  -51.9950                         Rio Xingu Camping
# 17 -159.3190       Sheraton Kauai Coconut Beach Resort
# 18  -56.3853                              FINCA SUAREZ
# 19  172.7902                        Isles Sunset Lodge
# 26  122.4157                   Nancy Montanes Bernardo
# 29 -120.4579  Holiday Inn Express Lompoc, an IHG Hotel
# 31  131.2500                        Waigo Splash Hotel
# 33 -155.0900                       Hilo Hawaiian Hotel
# 38  114.1577                              Mini Central

# %% [markdown]
# ## Drop any rows in the `hotel_df` DataFrame where a hotel name is not found and store the resulting data into a new DataFrame named `clean_hotel_df`.

# %%
# Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# Display sample data
clean_hotel_df.head()
# Out:
#                 City.1 Country  Max Temp Weather Description      lat  \
# 13           Hithadhoo      MV     81.07       broken clouds  -0.6000
# 14  Sao Felix Do Xingu      BR     82.20          light rain  -6.6447
# 17               Kapaa      US     80.92    scattered clouds  22.0752
# 18     Delta Del Tigre      UY     75.61       broken clouds -34.7633
# 19          Butaritari      KI     80.71       broken clouds   3.0707
#
#          lng                           Hotel Name
# 13   73.0833                    Scoop Guest House
# 14  -51.9950                    Rio Xingu Camping
# 17 -159.3190  Sheraton Kauai Coconut Beach Resort
# 18  -56.3853                         FINCA SUAREZ
# 19  172.7902                   Isles Sunset Lodge

# %% [markdown]
# **Note:** If the resulting DataFrame is empty, uncomment the following code to load sample data into the `clean_hotel_df`.

# %%
# In case of an empty DataFrame, load the sample data provided
# clean_hotel_df = pd.read_csv("WeatherPy_vacation-backup.csv")
# clean_hotel_df.head(10)

# %% [markdown]
# ## Create an CSV file to store the `clean_hotel_df` DataFrame as `WeatherPy_vacation.csv` in the Vacation_Search folder.

# %%
# Set the file name.
output_data_file = "WeatherPy_vacation.csv"

# Create a CSV file by using the clean_hotel_df DataFrame
clean_hotel_df.to_csv(output_data_file, index_label="ID")

# %% [markdown]
# ### Review the formatting template provided that you'll use to add an information box to each marker in the map.
#
# In the pop-up for each city you'll add:
#
# 1. The city name
#
# 2. The country code
#
# 3. The weather description and maximum temperature for the city

# %%
# Review the formatting template provided
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Weather Description} and {Max Temp} °F</dd>
</dl>
"""
clean_hotel_df.columns
# Out:
# Index(['City.1', 'Country', 'Max Temp', 'Weather Description', 'lat', 'lng',
#        'Hotel Name'],
#       dtype='object')

# %%
clean_hotel_df.rename({"City.1":"City"},axis=1,inplace=True)

# %%
for index , row in clean_hotel_df.iterrows():
    print(row)
# Out:
# City                           Hithadhoo
# Country                               MV
# Max Temp                           81.07
# Weather Description        broken clouds
# lat                                 -0.6
# lng                              73.0833
# Hotel Name             Scoop Guest House
# Name: 13, dtype: object
# City                   Sao Felix Do Xingu
# Country                                BR
# Max Temp                             82.2
# Weather Description            light rain
# lat                               -6.6447
# lng                               -51.995
# Hotel Name              Rio Xingu Camping
# Name: 14, dtype: object
# City                                                 Kapaa
# Country                                                 US
# Max Temp                                             80.92
# Weather Description                       scattered clouds
# lat                                                22.0752
# lng                                               -159.319
# Hotel Name             Sheraton Kauai Coconut Beach Resort
# Name: 17, dtype: object
# City                   Delta Del Tigre
# Country                             UY
# Max Temp                         75.61
# Weather Description      broken clouds
# lat                           -34.7633
# lng                           -56.3853
# Hotel Name                FINCA SUAREZ
# Name: 18, dtype: object
# City                           Butaritari
# Country                                KI
# Max Temp                            80.71
# Weather Description         broken clouds
# lat                                3.0707
# lng                              172.7902
# Hotel Name             Isles Sunset Lodge
# Name: 19, dtype: object
# City                               Dicabisagan
# Country                                     PH
# Max Temp                                 76.75
# Weather Description              moderate rain
# lat                                    17.0818
# lng                                   122.4157
# Hotel Name             Nancy Montanes Bernardo
# Name: 26, dtype: object
# City                                                     Lompoc
# Country                                                      US
# Max Temp                                                  75.78
# Weather Description                                   clear sky
# lat                                                     34.6391
# lng                                                   -120.4579
# Hotel Name             Holiday Inn Express Lompoc, an IHG Hotel
# Name: 29, dtype: object
# City                               Sorong
# Country                                ID
# Max Temp                            79.11
# Weather Description       overcast clouds
# lat                               -0.8833
# lng                                131.25
# Hotel Name             Waigo Splash Hotel
# Name: 31, dtype: object
# City                                  Hilo
# Country                                 US
# Max Temp                             84.25
# Weather Description       scattered clouds
# lat                                19.7297
# lng                                -155.09
# Hotel Name             Hilo Hawaiian Hotel
# Name: 33, dtype: object
# City                       Victoria
# Country                          HK
# Max Temp                      75.38
# Weather Description       clear sky
# lat                         22.2855
# lng                        114.1577
# Hotel Name             Mini Central
# Name: 38, dtype: object
# City                               Namatanai
# Country                                   PG
# Max Temp                               80.87
# Weather Description          overcast clouds
# lat                                  -3.6667
# lng                                 152.4333
# Hotel Name             Seagulls Inn Namatani
# Name: 39, dtype: object
# City                                 Sola
# Country                                VU
# Max Temp                            82.36
# Weather Description            few clouds
# lat                              -13.8833
# lng                                167.55
# Hotel Name             Leumerus Bungalows
# Name: 44, dtype: object
# City                                                  Neiafu
# Country                                                   TO
# Max Temp                                               78.51
# Weather Description                                clear sky
# lat                                                   -18.65
# lng                                                -173.9833
# Hotel Name             Mystic Sands Beachfront Accommodation
# Name: 50, dtype: object
# City                                                       La Palma
# Country                                                          US
# Max Temp                                                       81.5
# Weather Description                                   broken clouds
# lat                                                         33.8464
# lng                                                       -118.0467
# Hotel Name             La Quinta Inn & Suites by Wyndham Buena Park
# Name: 51, dtype: object
# City                         Sao Joao Da Barra
# Country                                     BR
# Max Temp                                 75.29
# Weather Description              broken clouds
# lat                                   -21.6403
# lng                                   -41.0511
# Hotel Name             Pousada Porto De Canoas
# Name: 52, dtype: object
# City                       Arraial Do Cabo
# Country                                 BR
# Max Temp                             75.06
# Weather Description       scattered clouds
# lat                               -22.9661
# lng                               -42.0278
# Hotel Name             Pousada Porto Praia
# Name: 55, dtype: object
# City                              Keti Bandar
# Country                                    PK
# Max Temp                                77.63
# Weather Description                 clear sky
# lat                                   24.1447
# lng                                   67.4497
# Hotel Name             Haji laloo memon house
# Name: 57, dtype: object
# City                                 Chiredzi
# Country                                    ZW
# Max Temp                                78.66
# Weather Description                 clear sky
# lat                                    -21.05
# lng                                   31.6667
# Hotel Name             Clevers Hotel Chiredzi
# Name: 64, dtype: object
# City                                               Faanui
# Country                                                PF
# Max Temp                                             79.3
# Weather Description                            light rain
# lat                                              -16.4833
# lng                                               -151.75
# Hotel Name             Bora-Bora Pearl Beach Resort & Spa
# Name: 65, dtype: object
# City                       Trincomalee
# Country                             LK
# Max Temp                         78.19
# Weather Description    overcast clouds
# lat                             8.5711
# lng                            81.2335
# Hotel Name              Welcombe Hotel
# Name: 66, dtype: object
# City                               Kloulklubed
# Country                                     PW
# Max Temp                                 82.63
# Weather Description            overcast clouds
# lat                                     7.0419
# lng                                   134.2556
# Hotel Name             Storyboard Beach Resort
# Name: 72, dtype: object
# City                         Tecoanapa
# Country                             MX
# Max Temp                         83.91
# Weather Description    overcast clouds
# lat                            16.5167
# lng                             -98.75
# Hotel Name             Hotel Manglares
# Name: 77, dtype: object
# City                              Weligama
# Country                                 LK
# Max Temp                             75.22
# Weather Description          broken clouds
# lat                                 5.9667
# lng                                80.4167
# Hotel Name             Weligama Bay Resort
# Name: 79, dtype: object
# City                                Puerto Ayora
# Country                                       EC
# Max Temp                                   76.96
# Weather Description                broken clouds
# lat                                      -0.7393
# lng                                     -90.3518
# Hotel Name             Finch Bay Galapagos Hotel
# Name: 80, dtype: object
# City                         Kununurra
# Country                             AU
# Max Temp                         78.78
# Weather Description          clear sky
# lat                           -15.7667
# lng                           128.7333
# Hotel Name             Hotel Kununurra
# Name: 82, dtype: object
# City                                        Sinnamary
# Country                                            GF
# Max Temp                                        80.67
# Weather Description                        few clouds
# lat                                            5.3833
# lng                                            -52.95
# Hotel Name             ALETHEIA Appartement Sinnamary
# Name: 90, dtype: object
# City                                       Port Keats
# Country                                            AU
# Max Temp                                        79.03
# Weather Description                   overcast clouds
# lat                                            -14.25
# lng                                            129.55
# Hotel Name             Kardu Durrikardu Numida Hostel
# Name: 93, dtype: object
# City                          Atuona
# Country                           PF
# Max Temp                       78.17
# Weather Description    broken clouds
# lat                             -9.8
# lng                        -139.0333
# Hotel Name               Villa Enata
# Name: 94, dtype: object
# City                               Vao
# Country                             NC
# Max Temp                         75.78
# Weather Description    overcast clouds
# lat                           -22.6667
# lng                           167.4833
# Hotel Name             Hotel Kou-Bugny
# Name: 96, dtype: object
# City                           Jawhar
# Country                            SO
# Max Temp                        75.78
# Weather Description         clear sky
# lat                            2.7809
# lng                           45.5005
# Hotel Name             Hotel Shabelle
# Name: 104, dtype: object
# City                                          Isla Vista
# Country                                               US
# Max Temp                                           75.99
# Weather Description                            clear sky
# lat                                              34.4133
# lng                                             -119.861
# Hotel Name             Best Western Plus South Coast Inn
# Name: 105, dtype: object
# City                      Qandala
# Country                        SO
# Max Temp                    76.35
# Weather Description    few clouds
# lat                        11.472
# lng                       49.8728
# Hotel Name
# Name: 107, dtype: object
# City                             Touros
# Country                              BR
# Max Temp                          78.89
# Weather Description    scattered clouds
# lat                             -5.1989
# lng                            -35.4608
# Hotel Name              INN NEW HORIZON
# Name: 109, dtype: object
# City                       Georgetown
# Country                            MY
# Max Temp                        80.24
# Weather Description        few clouds
# lat                            5.4112
# lng                          100.3354
# Hotel Name             Cititel Penang
# Name: 115, dtype: object
# City                                 Vaini
# Country                                 TO
# Max Temp                             77.29
# Weather Description          broken clouds
# lat                                  -21.2
# lng                                 -175.2
# Hotel Name             Keleti Beach Resort
# Name: 120, dtype: object
# City                        Mitsamiouli
# Country                              KM
# Max Temp                          78.03
# Weather Description    scattered clouds
# lat                            -11.3847
# lng                             43.2844
# Hotel Name                    Foyer ADM
# Name: 124, dtype: object
# City                                       Pedasi
# Country                                        PA
# Max Temp                                    79.07
# Weather Description                 moderate rain
# lat                                        7.5333
# lng                                      -80.0333
# Hotel Name             Hotel Casa de Campo Pedasí
# Name: 125, dtype: object
# City                   Providencia
# Country                         MX
# Max Temp                     81.41
# Weather Description      clear sky
# lat                        28.7167
# lng                      -111.5833
# Hotel Name
# Name: 127, dtype: object
# City                   Comodoro Rivadavia
# Country                                AR
# Max Temp                            80.46
# Weather Description         broken clouds
# lat                              -45.8667
# lng                                 -67.5
# Hotel Name                  Austral Hotel
# Name: 131, dtype: object
# City                        Sao Filipe
# Country                             CV
# Max Temp                         78.57
# Weather Description    overcast clouds
# lat                            14.8961
# lng                           -24.4956
# Hotel Name               Hotel Xaguate
# Name: 132, dtype: object
# City                                Pochutla
# Country                                   MX
# Max Temp                               89.82
# Weather Description               few clouds
# lat                                  15.7432
# lng                                 -96.4661
# Hotel Name             Hotel Posada San Jose
# Name: 135, dtype: object
# City                           Samarai
# Country                             PG
# Max Temp                         83.14
# Weather Description    overcast clouds
# lat                           -10.6167
# lng                           150.6667
# Hotel Name                   Nuli Sapi
# Name: 138, dtype: object
# City                              Bubaque
# Country                                GW
# Max Temp                            83.25
# Weather Description       overcast clouds
# lat                               11.2833
# lng                              -15.8333
# Hotel Name             Casa Dora, Bubaque
# Name: 139, dtype: object
# City                             Atar
# Country                            MR
# Max Temp                        78.35
# Weather Description         clear sky
# lat                           20.5169
# lng                          -13.0499
# Hotel Name             Oumou Elghoura
# Name: 145, dtype: object
# City                                 Luwuk
# Country                                 ID
# Max Temp                             77.11
# Weather Description        overcast clouds
# lat                                -0.9516
# lng                               122.7875
# Hotel Name             Hotel Santika Luwuk
# Name: 147, dtype: object
# City                              Buchanan
# Country                                 LR
# Max Temp                             78.98
# Weather Description             light rain
# lat                                 5.8808
# lng                               -10.0467
# Hotel Name             Kamaneahn Hotel Inc
# Name: 150, dtype: object
# City                            Progreso
# Country                               MX
# Max Temp                           82.11
# Weather Description           light rain
# lat                              21.2833
# lng                             -89.6667
# Hotel Name             Playa Linda Hotel
# Name: 153, dtype: object
# City                            Poum
# Country                           NC
# Max Temp                        77.9
# Weather Description    broken clouds
# lat                         -20.2333
# lng                         164.0167
# Hotel Name
# Name: 155, dtype: object
# City                        Praia Grande
# Country                               BR
# Max Temp                           75.34
# Weather Description            clear sky
# lat                             -24.0058
# lng                             -46.4028
# Hotel Name             Hotel Rota do Sol
# Name: 159, dtype: object
# City                               Kavieng
# Country                                 PG
# Max Temp                             82.87
# Weather Description        overcast clouds
# lat                                -2.5744
# lng                               150.7967
# Hotel Name             Nusa Island Retreat
# Name: 173, dtype: object
# City                            Avarua
# Country                             CK
# Max Temp                         78.85
# Weather Description    overcast clouds
# lat                           -21.2078
# lng                           -159.775
# Hotel Name                Paradise Inn
# Name: 177, dtype: object
# City                                   Santa Rosa
# Country                                        PH
# Max Temp                                    80.02
# Weather Description               overcast clouds
# lat                                       14.3122
# lng                                      121.1114
# Hotel Name             Erlyn’s Sta Rosa City Home
# Name: 186, dtype: object
# City                           Ondjiva
# Country                             AO
# Max Temp                         86.58
# Weather Description    overcast clouds
# lat                           -17.0667
# lng                            15.7333
# Hotel Name                    COMBUESA
# Name: 187, dtype: object
# City                               Idah
# Country                              NG
# Max Temp                          82.06
# Weather Description       broken clouds
# lat                              7.1065
# lng                              6.7342
# Hotel Name             Ubiga Hotel Idah
# Name: 188, dtype: object
# City                            Padang
# Country                             ID
# Max Temp                         75.25
# Weather Description    overcast clouds
# lat                            -0.9492
# lng                           100.3543
# Hotel Name              Mercure Padang
# Name: 193, dtype: object
# City                        Cockburn Town
# Country                                TC
# Max Temp                            82.36
# Weather Description      scattered clouds
# lat                               21.4612
# lng                              -71.1419
# Hotel Name             Osprey Beach Hotel
# Name: 200, dtype: object
# City                                        Axim
# Country                                       GH
# Max Temp                                    78.6
# Weather Description                broken clouds
# lat                                       4.8699
# lng                                      -2.2405
# Hotel Name             Axim Beach Resort And Spa
# Name: 202, dtype: object
# City                                        Kinablangan
# Country                                              PH
# Max Temp                                          76.68
# Weather Description                heavy intensity rain
# lat                                              7.6947
# lng                                            126.5503
# Hotel Name             Morales Eatery and Lodging House
# Name: 203, dtype: object
# City                              Moron
# Country                              AR
# Max Temp                          88.95
# Weather Description    scattered clouds
# lat                            -34.6534
# lng                            -58.6198
# Hotel Name                  Hotel Morón
# Name: 215, dtype: object
# City                                    Catuday
# Country                                      PH
# Max Temp                                  79.21
# Weather Description             overcast clouds
# lat                                     16.2923
# lng                                    119.8062
# Hotel Name             Benjie's Kubo & Cottages
# Name: 216, dtype: object
# City                                     Lorengau
# Country                                        PG
# Max Temp                                    82.29
# Weather Description               overcast clouds
# lat                                       -2.0226
# lng                                      147.2712
# Hotel Name             Lorengau Harbourside Hotel
# Name: 218, dtype: object
# City                             Pimenta Bueno
# Country                                     BR
# Max Temp                                 86.59
# Weather Description            overcast clouds
# lat                                   -11.6725
# lng                                   -61.1936
# Hotel Name             Cristalina Palace Hotel
# Name: 230, dtype: object
# City                            Envira
# Country                             BR
# Max Temp                         87.46
# Weather Description    overcast clouds
# lat                               -7.3
# lng                           -70.2167
# Hotel Name
# Name: 231, dtype: object
# City                                                          Palmerston
# Country                                                               AU
# Max Temp                                                           76.98
# Weather Description                                            clear sky
# lat                                                              -12.486
# lng                                                             130.9833
# Hotel Name             Quest Palmerston - Serviced Apartments and Acc...
# Name: 235, dtype: object
# City                           Cabo San Lucas
# Country                                    MX
# Max Temp                                83.61
# Weather Description                few clouds
# lat                                   22.8909
# lng                                 -109.9124
# Hotel Name             Hotel Tesoro Los Cabos
# Name: 241, dtype: object
# City                            Dingle
# Country                             PH
# Max Temp                         76.01
# Weather Description         light rain
# lat                            10.9995
# lng                           122.6711
# Hotel Name             SEGAYA PROPERTY
# Name: 251, dtype: object
# City                                  Buala
# Country                                  SB
# Max Temp                              81.99
# Weather Description           broken clouds
# lat                                  -8.145
# lng                                159.5921
# Hotel Name             Maringe Lagoon Lodge
# Name: 252, dtype: object
# City                          Viedma
# Country                           AR
# Max Temp                       79.59
# Weather Description        clear sky
# lat                         -40.8135
# lng                         -62.9967
# Hotel Name             Hotel Cristal
# Name: 254, dtype: object
# City                         Maldonado
# Country                             UY
# Max Temp                         75.22
# Weather Description    overcast clouds
# lat                           -34.6667
# lng                           -54.9167
# Hotel Name                La Cimarrona
# Name: 257, dtype: object
# City                                   Mount Isa
# Country                                       AU
# Max Temp                                   76.77
# Weather Description             scattered clouds
# lat                                     -20.7333
# lng                                        139.5
# Hotel Name             ibis Styles Mt Isa Verona
# Name: 264, dtype: object
# City                         Isangel
# Country                           VU
# Max Temp                       84.31
# Weather Description    broken clouds
# lat                           -19.55
# lng                         169.2667
# Hotel Name               Tanna Lodge
# Name: 267, dtype: object
# City                                  Port Moresby
# Country                                         PG
# Max Temp                                     80.02
# Weather Description                           haze
# lat                                        -9.4431
# lng                                       147.1797
# Hotel Name             Lamana Hotel (Port Moresby)
# Name: 271, dtype: object
# City                             Vila Velha
# Country                                  BR
# Max Temp                              75.15
# Weather Description           broken clouds
# lat                                -20.3297
# lng                                -40.2925
# Hotel Name             Hotel Vitória Palace
# Name: 274, dtype: object
# City                                                Kourou
# Country                                                 GF
# Max Temp                                             84.25
# Weather Description                             few clouds
# lat                                                 5.1552
# lng                                               -52.6478
# Hotel Name             Lodge TAKINI4 Guesthouse KOUROU FGU
# Name: 281, dtype: object
# City                        Bathsheba
# Country                            BB
# Max Temp                        83.01
# Weather Description        few clouds
# lat                           13.2167
# lng                          -59.5167
# Hotel Name             Atlantis Hotel
# Name: 284, dtype: object
# City                          Dangriga
# Country                             BZ
# Max Temp                         80.49
# Weather Description         light rain
# lat                            16.9692
# lng                           -88.2321
# Hotel Name             Chaleanor Hotel
# Name: 287, dtype: object
# City                            Tanete
# Country                             ID
# Max Temp                         75.15
# Weather Description    overcast clouds
# lat                            -3.9443
# lng                           119.7848
# Hotel Name             Wisma Tri Multi
# Name: 288, dtype: object
# City                               Bengkulu
# Country                                  ID
# Max Temp                               75.6
# Weather Description         overcast clouds
# lat                                 -3.8004
# lng                                102.2655
# Hotel Name             Grage Hotel Bengkulu
# Name: 289, dtype: object
# City                             Veraval
# Country                               IN
# Max Temp                           75.92
# Weather Description            clear sky
# lat                                 20.9
# lng                              70.3667
# Hotel Name             Lords Inn Somnath
# Name: 293, dtype: object
# City                                                        Road Town
# Country                                                            VG
# Max Temp                                                        82.49
# Weather Description                                         clear sky
# lat                                                           18.4167
# lng                                                          -64.6167
# Hotel Name             ZINGARA 76ft Catamaran, full crew-all included
# Name: 296, dtype: object
# City                           Luganville
# Country                                VU
# Max Temp                            82.31
# Weather Description             clear sky
# lat                              -15.5333
# lng                              167.1667
# Hotel Name             The Espiritu Hotel
# Name: 301, dtype: object
# City                                Palauig
# Country                                  PH
# Max Temp                              81.46
# Weather Description         overcast clouds
# lat                                  15.435
# lng                                119.9045
# Hotel Name             Villa Raphael Resort
# Name: 309, dtype: object
# City                       Kilindoni
# Country                           TZ
# Max Temp                        79.3
# Weather Description    broken clouds
# lat                          -7.9139
# lng                          39.6668
# Hotel Name               Bustani B&B
# Name: 324, dtype: object
# City                           Bourail
# Country                             NC
# Max Temp                         77.25
# Weather Description    overcast clouds
# lat                           -21.5667
# lng                           165.4833
# Hotel Name             Motel Allamanda
# Name: 326, dtype: object
# City                            Ouegoa
# Country                             NC
# Max Temp                         79.68
# Weather Description    overcast clouds
# lat                             -20.35
# lng                           164.4333
# Hotel Name
# Name: 327, dtype: object
# City                                              Mucurapo
# Country                                                 TT
# Max Temp                                             77.02
# Weather Description                          moderate rain
# lat                                                10.6667
# lng                                               -61.5333
# Hotel Name             Courtyard by Marriott Port of Spain
# Name: 339, dtype: object
# City                           Anloga
# Country                            GH
# Max Temp                        80.94
# Weather Description        few clouds
# lat                            5.7947
# lng                            0.8973
# Hotel Name             Pin Drop Hotel
# Name: 343, dtype: object
# City                            Uribia
# Country                             CO
# Max Temp                         84.87
# Weather Description    overcast clouds
# lat                            11.7139
# lng                            -72.266
# Hotel Name                Hotel Uribia
# Name: 359, dtype: object
# City                                                   Pontianak
# Country                                                       ID
# Max Temp                                                   76.98
# Weather Description                              overcast clouds
# lat                                                      -0.0333
# lng                                                     109.3333
# Hotel Name             Aston Pontianak Hotel & Convention Center
# Name: 360, dtype: object
# City                            Raga
# Country                           SS
# Max Temp                       75.72
# Weather Description    broken clouds
# lat                           8.4596
# lng                           25.678
# Hotel Name
# Name: 361, dtype: object
# City                         Viamao
# Country                          BR
# Max Temp                      77.68
# Weather Description       clear sky
# lat                        -30.0811
# lng                        -51.0233
# Hotel Name             OM B&B + Spa
# Name: 367, dtype: object
# City                            Koumac
# Country                             NC
# Max Temp                         78.64
# Weather Description    overcast clouds
# lat                           -20.5667
# lng                           164.2833
# Hotel Name                  Le Monitel
# Name: 368, dtype: object
# City                     Saint-Louis
# Country                           SN
# Max Temp                       87.44
# Weather Description    broken clouds
# lat                          16.3333
# lng                            -15.0
# Hotel Name
# Name: 378, dtype: object
# City                     Mtambile
# Country                        TZ
# Max Temp                    77.23
# Weather Description    light rain
# lat                       -5.3833
# lng                          39.7
# Hotel Name
# Name: 381, dtype: object
# City                                              Itarema
# Country                                                BR
# Max Temp                                            79.68
# Weather Description                            few clouds
# lat                                               -2.9248
# lng                                              -39.9167
# Hotel Name             Sea Lounge! Bar, Club & Restaurant
# Name: 383, dtype: object
# City                           Alofi
# Country                           NU
# Max Temp                       80.49
# Weather Description       few clouds
# lat                         -19.0595
# lng                        -169.9187
# Hotel Name             Taloa Heights
# Name: 385, dtype: object
# City                                   Soyo
# Country                                  AO
# Max Temp                              77.07
# Weather Description           broken clouds
# lat                                 -6.1349
# lng                                 12.3689
# Hotel Name             Hospedaria ndozi'ame
# Name: 387, dtype: object
# City                                   Lhokseumawe
# Country                                         ID
# Max Temp                                     76.44
# Weather Description                overcast clouds
# lat                                         5.1801
# lng                                        97.1507
# Hotel Name             OYO 3278 Penginapan Alfajri
# Name: 389, dtype: object
# City                        Tautira
# Country                          PF
# Max Temp                      76.46
# Weather Description      light rain
# lat                        -17.7333
# lng                         -149.15
# Hotel Name             Pension Oaoa
# Name: 391, dtype: object
# City                             Oussouye
# Country                                SN
# Max Temp                            80.78
# Weather Description       overcast clouds
# lat                                12.485
# lng                              -16.5469
# Hotel Name             Auberge du Routard
# Name: 392, dtype: object
# City                                     Takoradi
# Country                                        GH
# Max Temp                                    78.46
# Weather Description                 broken clouds
# lat                                        4.8845
# lng                                       -1.7554
# Hotel Name             Raybow International Hotel
# Name: 400, dtype: object
# City                                                    Salalah
# Country                                                      OM
# Max Temp                                                  78.89
# Weather Description                                  few clouds
# lat                                                     17.0151
# lng                                                     54.0924
# Hotel Name             HAMDAN PLAZA HOTEL SALALAH, an HTG Hotel
# Name: 402, dtype: object
# City                             Kimbe
# Country                             PG
# Max Temp                         78.49
# Weather Description    overcast clouds
# lat                            -5.5502
# lng                           150.1429
# Hotel Name             Kimbe Bay Hotel
# Name: 403, dtype: object
# City                           Kandrian
# Country                              PG
# Max Temp                          79.07
# Weather Description     overcast clouds
# lat                             -6.2167
# lng                              149.55
# Hotel Name             Kandrian Station
# Name: 409, dtype: object
# City                       Itaituba
# Country                          BR
# Max Temp                      87.96
# Weather Description      few clouds
# lat                         -4.2761
# lng                        -55.9836
# Hotel Name             Hotel Campos
# Name: 412, dtype: object
# City                       Narayanganj
# Country                             BD
# Max Temp                         75.22
# Weather Description          clear sky
# lat                            23.6233
# lng                            90.5011
# Hotel Name             BIMT Old Hostel
# Name: 414, dtype: object
# City                             Acarau
# Country                              BR
# Max Temp                          79.93
# Weather Description          few clouds
# lat                             -2.8856
# lng                              -40.12
# Hotel Name             castelo pizzaria
# Name: 415, dtype: object
# City                                   Matara
# Country                                    LK
# Max Temp                                75.81
# Weather Description             broken clouds
# lat                                    5.9485
# lng                                   80.5353
# Hotel Name             Amaloh Boutique Resort
# Name: 416, dtype: object
# City                   San Cristobal
# Country                           VE
# Max Temp                       78.98
# Weather Description    broken clouds
# lat                           7.7669
# lng                          -72.225
# Hotel Name                  Pirineos
# Name: 426, dtype: object
# City                          Port-Gentil
# Country                                GA
# Max Temp                            76.96
# Weather Description         broken clouds
# lat                               -0.7193
# lng                                8.7815
# Hotel Name             Fengshui Residence
# Name: 429, dtype: object
# City                     Caraballeda
# Country                           VE
# Max Temp                       85.37
# Weather Description    broken clouds
# lat                          10.6112
# lng                         -66.8522
# Hotel Name                Ole Caribe
# Name: 430, dtype: object
# City                           Cayenne
# Country                             GF
# Max Temp                         84.24
# Weather Description          clear sky
# lat                             4.9333
# lng                           -52.3333
# Hotel Name             Hôtel Le Dronmi
# Name: 434, dtype: object
# City                         Miramar
# Country                           US
# Max Temp                       78.82
# Weather Description       few clouds
# lat                          25.9873
# lng                         -80.2323
# Hotel Name             Stadium Hotel
# Name: 435, dtype: object
# City                               Miri
# Country                              MY
# Max Temp                          75.34
# Weather Description    scattered clouds
# lat                              4.4148
# lng                            114.0089
# Hotel Name             Mega Hotel, Miri
# Name: 436, dtype: object
# City                    Inhambane
# Country                        MZ
# Max Temp                    75.56
# Weather Description    few clouds
# lat                       -23.865
# lng                       35.3833
# Hotel Name                 Oceano
# Name: 446, dtype: object
# City                        Cubarral
# Country                           CO
# Max Temp                        76.8
# Weather Description    broken clouds
# lat                           3.7935
# lng                         -73.8406
# Hotel Name             Hotel Shaloom
# Name: 449, dtype: object
# City                                       Jardim
# Country                                        BR
# Max Temp                                    85.33
# Weather Description                     clear sky
# lat                                      -21.4803
# lng                                      -56.1381
# Hotel Name             Estancia Hotel - Jardim MS
# Name: 450, dtype: object
# City                         Luba
# Country                        GQ
# Max Temp                    79.29
# Weather Description    light rain
# lat                        3.4568
# lng                        8.5547
# Hotel Name
# Name: 457, dtype: object
# City                           Manggar
# Country                             ID
# Max Temp                         79.56
# Weather Description    overcast clouds
# lat                            -2.8833
# lng                           108.2667
# Hotel Name                 Guest Hotel
# Name: 461, dtype: object
# City                                   Saint-Georges
# Country                                           GD
# Max Temp                                       82.08
# Weather Description                    broken clouds
# lat                                          12.0564
# lng                                         -61.7485
# Hotel Name             Radisson Grenada Beach Resort
# Name: 462, dtype: object
# City                   Rio Das Pedras
# Country                            BR
# Max Temp                        76.64
# Weather Description         clear sky
# lat                          -22.8433
# lng                          -47.6061
# Hotel Name                    LucasDM
# Name: 464, dtype: object
# City                          San Carlos
# Country                               VE
# Max Temp                           78.21
# Weather Description      overcast clouds
# lat                               9.6612
# lng                             -68.5827
# Hotel Name             Hotel Paternopoli
# Name: 474, dtype: object
# City                              Auki
# Country                             SB
# Max Temp                         80.76
# Weather Description    overcast clouds
# lat                            -8.7676
# lng                           160.7034
# Hotel Name                  Auki Motel
# Name: 475, dtype: object
# City                                 Isla Mujeres
# Country                                        MX
# Max Temp                                    80.65
# Weather Description                    light rain
# lat                                       21.2311
# lng                                       -86.731
# Hotel Name             Hotel La Joya Isla Mujeres
# Name: 478, dtype: object
# City                          Kirakira
# Country                             SB
# Max Temp                         80.78
# Weather Description    overcast clouds
# lat                           -10.4544
# lng                           161.9205
# Hotel Name                SanBiz Lodge
# Name: 487, dtype: object
# City                                             Pilar
# Country                                             BR
# Max Temp                                         76.93
# Weather Description                         few clouds
# lat                                            -9.5972
# lng                                           -35.9567
# Hotel Name             Pousada e churrascaria Manguaba
# Name: 489, dtype: object
# City                          Mazatlan
# Country                             MX
# Max Temp                         84.16
# Weather Description         few clouds
# lat                            23.2167
# lng                          -106.4167
# Hotel Name             Hotel La Siesta
# Name: 492, dtype: object
# City                          Calabozo
# Country                             VE
# Max Temp                         80.94
# Weather Description    overcast clouds
# lat                             8.9242
# lng                           -67.4293
# Hotel Name              Hotel Giardini
# Name: 493, dtype: object
# City                              Nabire
# Country                               ID
# Max Temp                           76.06
# Weather Description      overcast clouds
# lat                              -3.3667
# lng                             135.4833
# Hotel Name             Hotel Nusantara I
# Name: 494, dtype: object
# City                                    Makakilo City
# Country                                            US
# Max Temp                                        82.72
# Weather Description                         clear sky
# lat                                           21.3469
# lng                                         -158.0858
# Hotel Name             Marriott's Ko Olina Beach Club
# Name: 499, dtype: object
# City                            Teluknaga
# Country                                ID
# Max Temp                            81.63
# Weather Description                  haze
# lat                               -6.0989
# lng                              106.6381
# Hotel Name             Teluk Naga Seliong
# Name: 500, dtype: object
# City                    Kavaratti
# Country                        IN
# Max Temp                    81.79
# Weather Description     clear sky
# lat                       10.5669
# lng                        72.642
# Hotel Name             Green leaf
# Name: 504, dtype: object
# City                                                   Paso De Carrasco
# Country                                                              UY
# Max Temp                                                          75.65
# Weather Description                                          light rain
# lat                                                            -34.8603
# lng                                                            -56.0522
# Hotel Name             Hotel Sofitel Montevideo Casino Carrasco and Spa
# Name: 506, dtype: object
# City                           Cilegon
# Country                             ID
# Max Temp                         79.52
# Weather Description    overcast clouds
# lat                            -6.0174
# lng                           106.0538
# Hotel Name                Forbis Hotel
# Name: 512, dtype: object
# City                                Banda Aceh
# Country                                     ID
# Max Temp                                 78.37
# Weather Description                 light rain
# lat                                     5.5577
# lng                                    95.3222
# Hotel Name             OYO 884 Rumoh PMI Hotel
# Name: 521, dtype: object
# City                           Kendari
# Country                             ID
# Max Temp                         75.34
# Weather Description    overcast clouds
# lat                             -3.945
# lng                           122.4989
# Hotel Name                 Hotel Wixel
# Name: 522, dtype: object
# City                      Ewa Beach
# Country                          US
# Max Temp                      84.15
# Weather Description       clear sky
# lat                         21.3156
# lng                       -158.0072
# Hotel Name             Base Lodging
# Name: 523, dtype: object
# City                                 Oistins
# Country                                   BB
# Max Temp                               82.49
# Weather Description               few clouds
# lat                                  13.0667
# lng                                 -59.5333
# Hotel Name             Butterfly Beach Hotel
# Name: 528, dtype: object
# City                           Jacareacanga
# Country                                  BR
# Max Temp                              81.45
# Weather Description    heavy intensity rain
# lat                                 -6.2222
# lng                                -57.7528
# Hotel Name                     Casa do Ian😎
# Name: 529, dtype: object
# City                                     Maceio
# Country                                      BR
# Max Temp                                  78.24
# Weather Description                  few clouds
# lat                                     -9.6658
# lng                                    -35.7353
# Hotel Name             Hotel Ponta Verde Maceió
# Name: 533, dtype: object
# City                        Qui Nhon
# Country                           VN
# Max Temp                       76.19
# Weather Description       few clouds
# lat                          13.7667
# lng                         109.2333
# Hotel Name             Seagull Hotel
# Name: 540, dtype: object
# City                                                 Tawau
# Country                                                 MY
# Max Temp                                             75.33
# Weather Description                        overcast clouds
# lat                                                 4.2498
# lng                                               117.8871
# Hotel Name             Shervinton Executive Boutique Hotel
# Name: 541, dtype: object
# City                               Eyl
# Country                             SO
# Max Temp                         76.98
# Weather Description          clear sky
# lat                             7.9803
# lng                            49.8164
# Hotel Name             EYL AQUE SYSTEM
# Name: 556, dtype: object
# City                            Pouebo
# Country                             NC
# Max Temp                         78.96
# Weather Description    overcast clouds
# lat                              -20.4
# lng                           164.5667
# Hotel Name                 RIVÂT LODGE
# Name: 558, dtype: object
# City                                     Juxtlahuaca
# Country                                           MX
# Max Temp                                       81.95
# Weather Description                  overcast clouds
# lat                                          17.4294
# lng                                         -99.1467
# Hotel Name             Casa de Huespedes "El centro"
# Name: 559, dtype: object
# City                              Yuli
# Country                             NG
# Max Temp                         77.11
# Weather Description    overcast clouds
# lat                             9.6989
# lng                            10.2744
# Hotel Name
# Name: 570, dtype: object
# City                                     Bac Lieu
# Country                                        VN
# Max Temp                                    78.22
# Weather Description               overcast clouds
# lat                                         9.285
# lng                                      105.7244
# Hotel Name             Khách sạn Sài Gòn Bạc Liêu
# Name: 571, dtype: object
# City                                             Eirunepe
# Country                                                BR
# Max Temp                                            87.49
# Weather Description                       overcast clouds
# lat                                               -6.6603
# lng                                              -69.8736
# Hotel Name             Hotel novo Acre & Comercial Aguiar
# Name: 572, dtype: object
# City                        Monrovia
# Country                           LR
# Max Temp                       78.67
# Weather Description    broken clouds
# lat                           6.3005
# lng                         -10.7969
# Hotel Name                Sunset Inn
# Name: 574, dtype: object
# City                          Celestun
# Country                             MX
# Max Temp                         79.95
# Weather Description    overcast clouds
# lat                            20.8667
# lng                              -90.4
# Hotel Name                Posada Lilia
# Name: 575, dtype: object
# City                                         Guanica
# Country                                           PR
# Max Temp                                       84.51
# Weather Description                        clear sky
# lat                                          17.9716
# lng                                          -66.908
# Hotel Name             Copamarina Beach Resort & Spa
# Name: 578, dtype: object
# City                     Frederico Westphalen
# Country                                    BR
# Max Temp                                77.45
# Weather Description                 clear sky
# lat                                  -27.3592
# lng                                  -53.3944
# Hotel Name             Hotel Palace Frederico
# Name: 590, dtype: object
# City                            Linares
# Country                              CL
# Max Temp                          85.53
# Weather Description    scattered clouds
# lat                              -35.85
# lng                               -71.6
# Hotel Name                   Hotel Real
# Name: 593, dtype: object
# City                             Cururupu
# Country                                BR
# Max Temp                             76.6
# Weather Description         broken clouds
# lat                               -1.8283
# lng                              -44.8683
# Hotel Name             POUSADA TRAVÉS'CIA
# Name: 594, dtype: object
# City                          Shakawe
# Country                            BW
# Max Temp                        80.55
# Weather Description         clear sky
# lat                          -18.3667
# lng                             21.85
# Hotel Name             EdenWood Lodge
# Name: 598, dtype: object
# City                    Vila Do Maio
# Country                           CV
# Max Temp                       77.79
# Weather Description    broken clouds
# lat                          15.1333
# lng                         -23.2167
# Hotel Name              Hotel Marilu
# Name: 600, dtype: object
# City                    Mogadishu
# Country                        SO
# Max Temp                    79.25
# Weather Description     clear sky
# lat                        2.0371
# lng                       45.3438
# Hotel Name             Hotel Juba
# Name: 603, dtype: object
# City                        Kulhudhuffushi
# Country                                 MV
# Max Temp                             80.98
# Weather Description        overcast clouds
# lat                                 6.6221
# lng                                  73.07
# Hotel Name             Haajy Guest House 1
# Name: 604, dtype: object
# City                        Eydhafushi
# Country                             MV
# Max Temp                         80.71
# Weather Description    overcast clouds
# lat                             5.1033
# lng                            73.0708
# Hotel Name                Soneva Fushi
# Name: 608, dtype: object
# City                              Poso
# Country                             ID
# Max Temp                         76.62
# Weather Description    overcast clouds
# lat                            -1.3959
# lng                           120.7524
# Hotel Name               Hotel 77 Poso
# Name: 611, dtype: object
# City                              Kahului
# Country                                US
# Max Temp                            84.22
# Weather Description            few clouds
# lat                               20.8947
# lng                               -156.47
# Hotel Name             Maui Seaside Hotel
# Name: 614, dtype: object
# City                            Cabedelo
# Country                               BR
# Max Temp                           79.47
# Weather Description            clear sky
# lat                              -6.9811
# lng                             -34.8339
# Hotel Name             Pousada Camboinha
# Name: 616, dtype: object
# City                    Hambantota
# Country                         LK
# Max Temp                     75.54
# Weather Description     few clouds
# lat                         6.1241
# lng                        81.1185
# Hotel Name             Bungalow 63
# Name: 617, dtype: object
# City                                          Salinopolis
# Country                                                BR
# Max Temp                                             80.6
# Weather Description                         broken clouds
# lat                                               -0.6136
# lng                                              -47.3561
# Hotel Name             Salinas Park Resort Maçarico AP101
# Name: 619, dtype: object
# City                        Marsh Harbour
# Country                                BS
# Max Temp                            76.75
# Weather Description      scattered clouds
# lat                               26.5412
# lng                              -77.0636
# Hotel Name             Abaco Beach Resort
# Name: 621, dtype: object
# City                   San Juan De Los Morros
# Country                                    VE
# Max Temp                                77.11
# Weather Description           overcast clouds
# lat                                    9.9115
# lng                                  -67.3538
# Hotel Name                   Hotel La Montaña
# Name: 622, dtype: object
# City                               Maloma
# Country                                PH
# Max Temp                            77.02
# Weather Description            light rain
# lat                               15.1135
# lng                              120.0639
# Hotel Name             Brandenburg Resort
# Name: 626, dtype: object
# City                            Pitimbu
# Country                              BR
# Max Temp                          79.39
# Weather Description          few clouds
# lat                             -7.4706
# lng                            -34.8086
# Hotel Name             Reserva do Abiaí
# Name: 627, dtype: object
# City                           Atambua
# Country                             ID
# Max Temp                         75.25
# Weather Description    overcast clouds
# lat                            -9.1061
# lng                           124.8925
# Hotel Name                Ros Muskanan
# Name: 632, dtype: object
# City                                          Dwarka
# Country                                           IN
# Max Temp                                       78.49
# Weather Description                        clear sky
# lat                                          22.2394
# lng                                          68.9678
# Hotel Name             Hotel Narayan Avezika Comfort
# Name: 651, dtype: object
# City                                   Denpasar
# Country                                      ID
# Max Temp                                  76.71
# Weather Description               broken clouds
# lat                                       -8.65
# lng                                    115.2167
# Hotel Name             OYO 3156 Hotel Warta Dua
# Name: 661, dtype: object
# City                            Bima
# Country                           ID
# Max Temp                       77.72
# Weather Description    broken clouds
# lat                          -8.4667
# lng                         118.7167
# Hotel Name             Lambitu Hotel
# Name: 664, dtype: object
# City                            Boa Vista
# Country                                BR
# Max Temp                            87.78
# Weather Description      scattered clouds
# lat                                2.8197
# lng                              -60.6733
# Hotel Name             Aipana Plaza Hotel
# Name: 665, dtype: object
# City                                     Olinda
# Country                                      BR
# Max Temp                                  80.33
# Weather Description            scattered clouds
# lat                                     -8.0089
# lng                                    -34.8553
# Hotel Name             Flat Quatro Rodas Olinda
# Name: 666, dtype: object
# City                      Abu Dhabi
# Country                          AE
# Max Temp                      78.82
# Weather Description       clear sky
# lat                         24.4667
# lng                         54.3667
# Hotel Name             Beach Rotana
# Name: 668, dtype: object
# City                      Brokopondo
# Country                           SR
# Max Temp                       85.73
# Weather Description    broken clouds
# lat                             4.75
# lng                         -55.1667
# Hotel Name               Matu Island
# Name: 670, dtype: object
# City                      Labuhan
# Country                        ID
# Max Temp                    78.24
# Weather Description    light rain
# lat                       -6.8844
# lng                      112.2051
# Hotel Name              DoubleFAG
# Name: 677, dtype: object
# City                          Aripuana
# Country                             BR
# Max Temp                         78.49
# Weather Description    overcast clouds
# lat                            -9.1667
# lng                           -60.6333
# Hotel Name
# Name: 679, dtype: object
# City                                        Chisec
# Country                                         GT
# Max Temp                                     82.63
# Weather Description                     light rain
# lat                                        15.8167
# lng                                       -90.2833
# Hotel Name             Hotel Estancia De La Virgen
# Name: 680, dtype: object
# City                              Loiza
# Country                              PR
# Max Temp                           83.8
# Weather Description    scattered clouds
# lat                             18.4313
# lng                            -65.8802
# Hotel Name              Vacation Realty
# Name: 683, dtype: object
# City                      Kantunilkin
# Country                            MX
# Max Temp                        79.63
# Weather Description        light rain
# lat                           21.0917
# lng                            -87.45
# Hotel Name             Posada Paraiso
# Name: 684, dtype: object
# City                                Guanare
# Country                                  VE
# Max Temp                              89.62
# Weather Description         overcast clouds
# lat                                  9.0418
# lng                                -69.7421
# Hotel Name             Nuevo Hotel Coromoto
# Name: 686, dtype: object
# City                                 Dogondoutchi
# Country                                        NE
# Max Temp                                    78.53
# Weather Description                 broken clouds
# lat                                       13.6393
# lng                                        4.0287
# Hotel Name             Hôtel Alheri Maison Alheri
# Name: 695, dtype: object
# City                                            Moranbah
# Country                                               AU
# Max Temp                                            75.6
# Weather Description                      overcast clouds
# lat                                             -22.0016
# lng                                             148.0466
# Hotel Name             Property Vine - Monterey Moranbah
# Name: 696, dtype: object
# City                     Bahia De Caraquez
# Country                                 EC
# Max Temp                             75.38
# Weather Description        overcast clouds
# lat                                   -0.6
# lng                               -80.4167
# Hotel Name             Saiananda Eco-Hotel
# Name: 700, dtype: object
# City                        Carutapera
# Country                             BR
# Max Temp                         77.61
# Weather Description    overcast clouds
# lat                             -1.195
# lng                             -46.02
# Hotel Name                      Lidera
# Name: 702, dtype: object
# City                              Lakatoro
# Country                                 VU
# Max Temp                             83.64
# Weather Description             few clouds
# lat                               -16.0999
# lng                               167.4164
# Hotel Name             Lakatoro Palm Lodge
# Name: 705, dtype: object
# City                                   Rio Grande
# Country                                        BR
# Max Temp                                    82.51
# Weather Description              scattered clouds
# lat                                       -32.035
# lng                                      -52.0986
# Hotel Name             Hotel Atlântico Rio Grande
# Name: 706, dtype: object
# City                              Alappuzha
# Country                                  IN
# Max Temp                               77.0
# Weather Description              light rain
# lat                                    9.49
# lng                                 76.3264
# Hotel Name             Panoramic Sea Resort
# Name: 710, dtype: object

# %% [markdown]
# ## Review the provided list comprehension code to retrieve the city data from each row, which will then be added to the formatting template and saved in the `hotel_info` list.

# %%
# Get the data from each row in the clean_hotel_df DataFrame, add it to the formatting template, and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# Display sample data
hotel_info[:10]
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Scoop Guest House</dd>\n<dt>City</dt><dd>Hithadhoo</dd>\n<dt>Country</dt><dd>MV</dd>\n<dt>Current Weather</dt><dd>broken clouds and 81.07 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rio Xingu Camping</dd>\n<dt>City</dt><dd>Sao Felix Do Xingu</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Weather</dt><dd>light rain and 82.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sheraton Kauai Coconut Beach Resort</dd>\n<dt>City</dt><dd>Kapaa</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>scattered clouds and 80.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>FINCA SUAREZ</dd>\n<dt>City</dt><dd>Delta Del Tigre</dd>\n<dt>Country</dt><dd>UY</dd>\n<dt>Current Weather</dt><dd>broken clouds and 75.61 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Isles Sunset Lodge</dd>\n<dt>City</dt><dd>Butaritari</dd>\n<dt>Country</dt><dd>KI</dd>\n<dt>Current Weather</dt><dd>broken clouds and 80.71 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Nancy Montanes Bernardo</dd>\n<dt>City</dt><dd>Dicabisagan</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Current Weather</dt><dd>moderate rain and 76.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>clear sky and 75.78 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Waigo Splash Hotel</dd>\n<dt>City</dt><dd>Sorong</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Weather</dt><dd>overcast clouds and 79.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Current Weather</dt><dd>scattered clouds and 84.25 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mini Central</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Current Weather</dt><dd>clear sky and 75.38 °F</dd>\n</dl>\n']

# %% [markdown]
# ## Use the provided code snippet to retrieve the latitude and longitude from each row and store them in a new DataFrame called `locations`.

# %%
# Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["lat", "lng"]]

# Display sample data
locations.head(10)
# Out:
#         lat       lng
# 13  -0.6000   73.0833
# 14  -6.6447  -51.9950
# 17  22.0752 -159.3190
# 18 -34.7633  -56.3853
# 19   3.0707  172.7902
# 26  17.0818  122.4157
# 29  34.6391 -120.4579
# 31  -0.8833  131.2500
# 33  19.7297 -155.0900
# 38  22.2855  114.1577

# %% [markdown]
# ## Refactor your previous marker layer map code to create a marker layer map that will have pop-up markers for each city on the map.

# %%
# Add a marker layer for each city to the map. 
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

# Create a figure to add the Google map as a layer
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
fig.add_layer(marker_layer)

# Display the figure containing the map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
