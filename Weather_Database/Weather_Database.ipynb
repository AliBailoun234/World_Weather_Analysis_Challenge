# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 785

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from API import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        print("city_weather =", city_weather)
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloud = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City":city.title(),
                         "lat":city_lat,
                         "lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity":city_humidity,
                         "Cloudiness":city_cloud,
                         "Windiness":city_wind,
                         "Country":city_country,
                         "Weather Description":city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# city_weather = {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 5.67, 'feels_like': -6.93, 'temp_min': 5.67, 'temp_max': 5.67, 'pressure': 986, 'humidity': 95, 'sea_level': 986, 'grnd_level': 980}, 'visibility': 134, 'wind': {'speed': 15.86, 'deg': 79, 'gust': 19.3}, 'snow': {'1h': 0.36}, 'clouds': {'all': 100}, 'dt': 1668719581, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# Processing Record 2 of Set 1 | tura
# city_weather = {'coord': {'lon': 90.2201, 'lat': 25.5198}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.87, 'feels_like': 60.84, 'temp_min': 60.87, 'temp_max': 60.87, 'pressure': 1013, 'humidity': 89, 'sea_level': 1013, 'grnd_level': 969}, 'visibility': 10000, 'wind': {'speed': 3.89, 'deg': 52, 'gust': 3.38}, 'clouds': {'all': 0}, 'dt': 1668719021, 'sys': {'country': 'IN', 'sunrise': 1668730714, 'sunset': 1668769807}, 'timezone': 19800, 'id': 1254046, 'name': 'Tura', 'cod': 200}
# Processing Record 3 of Set 1 | rikitea
# city_weather = {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 72.16, 'feels_like': 73.11, 'temp_min': 72.16, 'temp_max': 72.16, 'pressure': 1012, 'humidity': 86, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 3.24, 'deg': 236, 'gust': 4.21}, 'rain': {'1h': 0.42}, 'clouds': {'all': 100}, 'dt': 1668719581, 'sys': {'country': 'PF', 'sunrise': 1668694034, 'sunset': 1668741769}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 4 of Set 1 | severo-kurilsk
# city_weather = {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 33.75, 'feels_like': 24.1, 'temp_min': 33.75, 'temp_max': 33.75, 'pressure': 1018, 'humidity': 69, 'sea_level': 1018, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 14.23, 'deg': 351, 'gust': 18.19}, 'clouds': {'all': 100}, 'dt': 1668719156, 'sys': {'country': 'RU', 'sunrise': 1668718480, 'sunset': 1668750403}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# Processing Record 5 of Set 1 | chokurdakh
# city_weather = {'coord': {'lon': 147.9167, 'lat': 70.6333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -10.41, 'feels_like': -23.01, 'temp_min': -10.41, 'temp_max': -10.41, 'pressure': 1019, 'humidity': 95, 'sea_level': 1019, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 6.15, 'deg': 42, 'gust': 8.25}, 'clouds': {'all': 99}, 'dt': 1668719581, 'sys': {'country': 'RU', 'sunrise': 1668731602, 'sunset': 1668741221}, 'timezone': 39600, 'id': 2126123, 'name': 'Chokurdakh', 'cod': 200}
# Processing Record 6 of Set 1 | port elizabeth
# city_weather = {'coord': {'lon': 25.5701, 'lat': -33.918}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.32, 'feels_like': 63.39, 'temp_min': 63.32, 'temp_max': 65.1, 'pressure': 1018, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 189, 'gust': 5.99}, 'clouds': {'all': 100}, 'dt': 1668719163, 'sys': {'type': 2, 'id': 2072678, 'country': 'ZA', 'sunrise': 1668654301, 'sunset': 1668704431}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}
# Processing Record 7 of Set 1 | sitka
# city_weather = {'coord': {'lon': -135.33, 'lat': 57.0531}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 44.49, 'feels_like': 42.03, 'temp_min': 44.49, 'temp_max': 44.49, 'pressure': 1034, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 320}, 'clouds': {'all': 20}, 'dt': 1668719094, 'sys': {'type': 1, 'id': 7795, 'country': 'US', 'sunrise': 1668703665, 'sunset': 1668732311}, 'timezone': -32400, 'id': 5557293, 'name': 'Sitka', 'cod': 200}
# Processing Record 8 of Set 1 | sale
# city_weather = {'coord': {'lon': -6.8166, 'lat': 34.0389}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.79, 'feels_like': 64.56, 'temp_min': 63.28, 'temp_max': 65.75, 'pressure': 1019, 'humidity': 100}, 'visibility': 5000, 'wind': {'speed': 4.61, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1668719582, 'sys': {'type': 1, 'id': 2402, 'country': 'MA', 'sunrise': 1668668502, 'sunset': 1668705778}, 'timezone': 3600, 'id': 2537763, 'name': 'Salé', 'cod': 200}
# Processing Record 9 of Set 1 | northam
# city_weather = {'coord': {'lon': -4.2167, 'lat': 51.0333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 50.49, 'feels_like': 49.05, 'temp_min': 45.66, 'temp_max': 51.62, 'pressure': 994, 'humidity': 81, 'sea_level': 994, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 20.02, 'deg': 294, 'gust': 27.18}, 'clouds': {'all': 28}, 'dt': 1668719582, 'sys': {'type': 2, 'id': 2005965, 'country': 'GB', 'sunrise': 1668670584, 'sunset': 1668702448}, 'timezone': 0, 'id': 2641434, 'name': 'Northam', 'cod': 200}
# Processing Record 10 of Set 1 | pierre
# city_weather = {'coord': {'lon': -100.351, 'lat': 44.3683}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 20.32, 'feels_like': 7.72, 'temp_min': 18.28, 'temp_max': 20.32, 'pressure': 1028, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 26.46, 'deg': 330, 'gust': 39.12}, 'clouds': {'all': 100}, 'dt': 1668719425, 'sys': {'type': 1, 'id': 5361, 'country': 'US', 'sunrise': 1668692413, 'sunset': 1668726770}, 'timezone': -21600, 'id': 5767918, 'name': 'Pierre', 'cod': 200}
# Processing Record 11 of Set 1 | klaksvik
# city_weather = {'coord': {'lon': -6.589, 'lat': 62.2266}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 47.32, 'feels_like': 37.9, 'temp_min': 47.32, 'temp_max': 47.32, 'pressure': 1002, 'humidity': 83, 'sea_level': 1002, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 33.67, 'deg': 141, 'gust': 38.88}, 'rain': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1668719088, 'sys': {'type': 1, 'id': 1596, 'country': 'FO', 'sunrise': 1668674679, 'sunset': 1668699492}, 'timezone': 0, 'id': 2618795, 'name': 'Klaksvík', 'cod': 200}
# Processing Record 12 of Set 1 | nikolskoye
# city_weather = {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 29.97, 'feels_like': 23.99, 'temp_min': 28.78, 'temp_max': 30.09, 'pressure': 1019, 'humidity': 87, 'sea_level': 1019, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 5.77, 'deg': 61, 'gust': 16.33}, 'clouds': {'all': 8}, 'dt': 1668719021, 'sys': {'type': 2, 'id': 47750, 'country': 'RU', 'sunrise': 1668751187, 'sunset': 1668777867}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# Processing Record 13 of Set 1 | taolanaro
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 14 of Set 1 | ponta do sol
# city_weather = {'coord': {'lon': -17.1, 'lat': 32.6667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 67.77, 'feels_like': 67.77, 'temp_min': 66.13, 'temp_max': 69.71, 'pressure': 1023, 'humidity': 75, 'sea_level': 1023, 'grnd_level': 1023}, 'visibility': 10000, 'wind': {'speed': 6.58, 'deg': 331, 'gust': 7.52}, 'clouds': {'all': 53}, 'dt': 1668719583, 'sys': {'type': 2, 'id': 2008291, 'country': 'PT', 'sunrise': 1668670810, 'sunset': 1668708407}, 'timezone': 0, 'id': 2264557, 'name': 'Ponta do Sol', 'cod': 200}
# Processing Record 15 of Set 1 | hithadhoo
# city_weather = {'coord': {'lon': 73.0833, 'lat': -0.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 81.07, 'feels_like': 85.46, 'temp_min': 81.07, 'temp_max': 81.07, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 12.44, 'deg': 260, 'gust': 13.42}, 'clouds': {'all': 64}, 'dt': 1668719017, 'sys': {'country': 'MV', 'sunrise': 1668732513, 'sunset': 1668776235}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 16 of Set 1 | sao felix do xingu
# city_weather = {'coord': {'lon': -51.995, 'lat': -6.6447}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82.2, 'feels_like': 86.14, 'temp_min': 82.2, 'temp_max': 82.2, 'pressure': 1007, 'humidity': 67, 'sea_level': 1007, 'grnd_level': 985}, 'visibility': 10000, 'wind': {'speed': 1.83, 'deg': 3, 'gust': 2.04}, 'rain': {'1h': 0.19}, 'clouds': {'all': 94}, 'dt': 1668719348, 'sys': {'country': 'BR', 'sunrise': 1668675620, 'sunset': 1668720349}, 'timezone': -10800, 'id': 3388847, 'name': 'São Félix do Xingu', 'cod': 200}
# Processing Record 17 of Set 1 | yellowknife
# city_weather = {'coord': {'lon': -114.3525, 'lat': 62.456}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 17.56, 'feels_like': 4.96, 'temp_min': 17.56, 'temp_max': 17.56, 'pressure': 1033, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.99, 'deg': 290}, 'clouds': {'all': 49}, 'dt': 1668719584, 'sys': {'type': 2, 'id': 47671, 'country': 'CA', 'sunrise': 1668700702, 'sunset': 1668725203}, 'timezone': -25200, 'id': 6185377, 'name': 'Yellowknife', 'cod': 200}
# Processing Record 18 of Set 1 | bethel
# city_weather = {'coord': {'lon': -73.414, 'lat': 41.3712}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 41.52, 'feels_like': 34.16, 'temp_min': 39.34, 'temp_max': 43.54, 'pressure': 1012, 'humidity': 51}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 270, 'gust': 25.32}, 'clouds': {'all': 40}, 'dt': 1668719578, 'sys': {'type': 2, 'id': 2004826, 'country': 'US', 'sunrise': 1668685473, 'sunset': 1668720779}, 'timezone': -18000, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 19 of Set 1 | kapaa
# city_weather = {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.11, 'feels_like': 83.52, 'temp_min': 79.48, 'temp_max': 80.92, 'pressure': 1019, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 50}, 'clouds': {'all': 40}, 'dt': 1668719412, 'sys': {'type': 2, 'id': 2005473, 'country': 'US', 'sunrise': 1668703851, 'sunset': 1668743641}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 20 of Set 1 | delta del tigre
# city_weather = {'coord': {'lon': -56.3853, 'lat': -34.7633}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.61, 'feels_like': 75.04, 'temp_min': 75.31, 'temp_max': 75.61, 'pressure': 1017, 'humidity': 46}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1668719584, 'sys': {'type': 1, 'id': 8687, 'country': 'UY', 'sunrise': 1668673854, 'sunset': 1668724223}, 'timezone': -10800, 'id': 3442778, 'name': 'Delta del Tigre', 'cod': 200}
# Processing Record 21 of Set 1 | butaritari
# city_weather = {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.71, 'feels_like': 84.76, 'temp_min': 80.71, 'temp_max': 80.71, 'pressure': 1011, 'humidity': 74, 'sea_level': 1011, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 16.2, 'deg': 125, 'gust': 17.2}, 'clouds': {'all': 60}, 'dt': 1668719585, 'sys': {'country': 'KI', 'sunrise': 1668708885, 'sunset': 1668751997}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# Processing Record 22 of Set 1 | lagoa
# city_weather = {'coord': {'lon': -27.9833, 'lat': 39.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.67, 'feels_like': 59.27, 'temp_min': 60.67, 'temp_max': 60.67, 'pressure': 1027, 'humidity': 60, 'sea_level': 1027, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 12.15, 'deg': 327, 'gust': 13.33}, 'clouds': {'all': 5}, 'dt': 1668719235, 'sys': {'country': 'PT', 'sunrise': 1668674229, 'sunset': 1668710213}, 'timezone': -3600, 'id': 3372964, 'name': 'Lagoa', 'cod': 200}
# Processing Record 23 of Set 1 | yulara
# city_weather = {'coord': {'lon': 130.9889, 'lat': -25.2406}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 69.58, 'feels_like': 69.96, 'temp_min': 69.58, 'temp_max': 69.58, 'pressure': 1006, 'humidity': 79, 'sea_level': 1006, 'grnd_level': 949}, 'visibility': 10000, 'wind': {'speed': 11.99, 'deg': 333, 'gust': 23.94}, 'clouds': {'all': 2}, 'dt': 1668719585, 'sys': {'country': 'AU', 'sunrise': 1668716380, 'sunset': 1668764569}, 'timezone': 34200, 'id': 6355222, 'name': 'Yulara', 'cod': 200}
# Processing Record 24 of Set 1 | barrow
# city_weather = {'coord': {'lon': -156.7887, 'lat': 71.2906}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 26.62, 'feels_like': 18.25, 'temp_min': 26.62, 'temp_max': 26.62, 'pressure': 1022, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 160}, 'clouds': {'all': 0}, 'dt': 1668719585, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1668719943, 'sunset': 1668726334}, 'timezone': -32400, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 25 of Set 1 | cap malheureux
# city_weather = {'coord': {'lon': 57.6142, 'lat': -19.9842}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 69.48, 'feels_like': 69.08, 'temp_min': 69.48, 'temp_max': 69.48, 'pressure': 1015, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 166, 'gust': 7}, 'clouds': {'all': 28}, 'dt': 1668719309, 'sys': {'type': 2, 'id': 2002134, 'country': 'MU', 'sunrise': 1668734518, 'sunset': 1668781657}, 'timezone': 14400, 'id': 934649, 'name': 'Cap Malheureux', 'cod': 200}
# Processing Record 26 of Set 1 | ushuaia
# city_weather = {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.46, 'feels_like': 49.03, 'temp_min': 51.46, 'temp_max': 51.46, 'pressure': 996, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 19.57, 'deg': 240}, 'clouds': {'all': 75}, 'dt': 1668719586, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1668672858, 'sunset': 1668730939}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 27 of Set 1 | esperance
# city_weather = {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 56.44, 'feels_like': 55.45, 'temp_min': 56.44, 'temp_max': 56.44, 'pressure': 1001, 'humidity': 78, 'sea_level': 1001, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 15.66, 'deg': 271, 'gust': 21.99}, 'clouds': {'all': 67}, 'dt': 1668719025, 'sys': {'country': 'AU', 'sunrise': 1668717564, 'sunset': 1668767748}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 28 of Set 1 | dicabisagan
# city_weather = {'coord': {'lon': 122.4157, 'lat': 17.0818}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 76.75, 'feels_like': 78.26, 'temp_min': 76.75, 'temp_max': 76.75, 'pressure': 1013, 'humidity': 88, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 2.55, 'deg': 327, 'gust': 3.15}, 'rain': {'1h': 1.26}, 'clouds': {'all': 99}, 'dt': 1668719586, 'sys': {'country': 'PH', 'sunrise': 1668722179, 'sunset': 1668762886}, 'timezone': 28800, 'id': 1715015, 'name': 'Dicabisagan', 'cod': 200}
# Processing Record 29 of Set 1 | yatou
# city_weather = {'coord': {'lon': 122.3833, 'lat': 37.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 49.33, 'feels_like': 49.33, 'temp_min': 49.33, 'temp_max': 49.33, 'pressure': 1026, 'humidity': 73, 'sea_level': 1026, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 1.16, 'deg': 268, 'gust': 1.95}, 'clouds': {'all': 3}, 'dt': 1668719586, 'sys': {'country': 'CN', 'sunrise': 1668724323, 'sunset': 1668760758}, 'timezone': 28800, 'id': 1786855, 'name': 'Yatou', 'cod': 200}
# Processing Record 30 of Set 1 | kodiak
# city_weather = {'coord': {'lon': -152.4072, 'lat': 57.79}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 42.31, 'feels_like': 35.17, 'temp_min': 42.31, 'temp_max': 42.31, 'pressure': 1031, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 80}, 'clouds': {'all': 100}, 'dt': 1668719332, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1668708006, 'sunset': 1668736168}, 'timezone': -32400, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 31 of Set 1 | lompoc
# city_weather = {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.99, 'feels_like': 66.99, 'temp_min': 64.6, 'temp_max': 75.78, 'pressure': 1021, 'humidity': 30}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1668719587, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1668695867, 'sunset': 1668732969}, 'timezone': -28800, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 32 of Set 1 | vestmannaeyjar
# city_weather = {'coord': {'lon': -20.2734, 'lat': 63.4427}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 46.62, 'feels_like': 39.85, 'temp_min': 46.62, 'temp_max': 46.62, 'pressure': 988, 'humidity': 84, 'sea_level': 988, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 16.87, 'deg': 128, 'gust': 21.32}, 'clouds': {'all': 71}, 'dt': 1668719587, 'sys': {'country': 'IS', 'sunrise': 1668678570, 'sunset': 1668702170}, 'timezone': 0, 'id': 3412093, 'name': 'Vestmannaeyjar', 'cod': 200}
# Processing Record 33 of Set 1 | sorong
# city_weather = {'coord': {'lon': 131.25, 'lat': -0.8833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.11, 'feels_like': 79.11, 'temp_min': 79.11, 'temp_max': 79.11, 'pressure': 1007, 'humidity': 87, 'sea_level': 1007, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 4.94, 'deg': 147, 'gust': 5.44}, 'clouds': {'all': 100}, 'dt': 1668719587, 'sys': {'country': 'ID', 'sunrise': 1668718528, 'sunset': 1668762297}, 'timezone': 32400, 'id': 1626542, 'name': 'Sorong', 'cod': 200}
# Processing Record 34 of Set 1 | castro
# city_weather = {'coord': {'lon': -50.0119, 'lat': -24.7911}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 68.56, 'feels_like': 67.69, 'temp_min': 68.56, 'temp_max': 68.56, 'pressure': 1015, 'humidity': 55, 'sea_level': 1015, 'grnd_level': 905}, 'visibility': 10000, 'wind': {'speed': 5.21, 'deg': 112, 'gust': 9.86}, 'clouds': {'all': 2}, 'dt': 1668719588, 'sys': {'country': 'BR', 'sunrise': 1668673477, 'sunset': 1668721540}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 35 of Set 1 | ambodifototra
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 36 of Set 1 | hilo
# city_weather = {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 81.68, 'feels_like': 87.57, 'temp_min': 81.1, 'temp_max': 84.25, 'pressure': 1018, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 110}, 'clouds': {'all': 40}, 'dt': 1668719589, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1668702615, 'sunset': 1668742847}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 37 of Set 1 | cape town
# city_weather = {'coord': {'lon': 18.4232, 'lat': -33.9258}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.33, 'feels_like': 59.27, 'temp_min': 59.88, 'temp_max': 61.12, 'pressure': 1016, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 148, 'gust': 20}, 'clouds': {'all': 100}, 'dt': 1668719589, 'sys': {'type': 2, 'id': 2073005, 'country': 'ZA', 'sunrise': 1668656015, 'sunset': 1668706149}, 'timezone': 7200, 'id': 3369157, 'name': 'Cape Town', 'cod': 200}
# Processing Record 38 of Set 1 | anan
# city_weather = {'coord': {'lon': 134.65, 'lat': 33.9167}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 55.98, 'feels_like': 54.32, 'temp_min': 55.98, 'temp_max': 55.98, 'pressure': 1025, 'humidity': 65, 'sea_level': 1025, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 7.76, 'deg': 348, 'gust': 9.06}, 'clouds': {'all': 0}, 'dt': 1668719589, 'sys': {'country': 'JP', 'sunrise': 1668720970, 'sunset': 1668758222}, 'timezone': 32400, 'id': 1865309, 'name': 'Anan', 'cod': 200}
# Processing Record 39 of Set 1 | norman wells
# city_weather = {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 16.32, 'feels_like': 16.32, 'temp_min': 16.32, 'temp_max': 16.32, 'pressure': 1035, 'humidity': 79, 'sea_level': 1035, 'grnd_level': 1027}, 'visibility': 10000, 'wind': {'speed': 2.66, 'deg': 327, 'gust': 2.62}, 'clouds': {'all': 32}, 'dt': 1668719314, 'sys': {'country': 'CA', 'sunrise': 1668705275, 'sunset': 1668726622}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# Processing Record 40 of Set 1 | dukat
# city_weather = {'coord': {'lon': 155.55, 'lat': 62.55}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -18.18, 'feels_like': -27.44, 'temp_min': -18.18, 'temp_max': -18.18, 'pressure': 1020, 'humidity': 99, 'sea_level': 1020, 'grnd_level': 919}, 'visibility': 1187, 'wind': {'speed': 3, 'deg': 351, 'gust': 3.02}, 'clouds': {'all': 100}, 'dt': 1668719589, 'sys': {'country': 'RU', 'sunrise': 1668722414, 'sunset': 1668746745}, 'timezone': 39600, 'id': 2125906, 'name': 'Dukat', 'cod': 200}
# Processing Record 41 of Set 1 | barentsburg
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 42 of Set 1 | victoria
# city_weather = {'coord': {'lon': 114.1577, 'lat': 22.2855}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 74.3, 'feels_like': 75.56, 'temp_min': 71.96, 'temp_max': 75.38, 'pressure': 1015, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1668718891, 'sys': {'type': 2, 'id': 2035800, 'country': 'HK', 'sunrise': 1668724647, 'sunset': 1668764383}, 'timezone': 28800, 'id': 1819729, 'name': 'Hong Kong', 'cod': 200}
# Processing Record 43 of Set 1 | namatanai
# city_weather = {'coord': {'lon': 152.4333, 'lat': -3.6667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.87, 'feels_like': 85.06, 'temp_min': 80.87, 'temp_max': 80.87, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 6.22, 'deg': 84, 'gust': 7.85}, 'clouds': {'all': 100}, 'dt': 1668719296, 'sys': {'country': 'PG', 'sunrise': 1668713211, 'sunset': 1668757444}, 'timezone': 36000, 'id': 2090021, 'name': 'Namatanai', 'cod': 200}
# Processing Record 44 of Set 1 | turayf
# city_weather = {'coord': {'lon': 38.6637, 'lat': 31.6725}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 56.59, 'feels_like': 54.68, 'temp_min': 56.59, 'temp_max': 56.59, 'pressure': 1018, 'humidity': 58, 'sea_level': 1018, 'grnd_level': 923}, 'visibility': 10000, 'wind': {'speed': 3.58, 'deg': 303, 'gust': 3.8}, 'clouds': {'all': 0}, 'dt': 1668719422, 'sys': {'country': 'SA', 'sunrise': 1668743757, 'sunset': 1668781515}, 'timezone': 10800, 'id': 101312, 'name': 'Turaif', 'cod': 200}
# Processing Record 45 of Set 1 | pacific grove
# city_weather = {'coord': {'lon': -121.9166, 'lat': 36.6177}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 58.03, 'feels_like': 56.53, 'temp_min': 54.43, 'temp_max': 68.38, 'pressure': 1022, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 5.99, 'deg': 5, 'gust': 10}, 'clouds': {'all': 0}, 'dt': 1668719020, 'sys': {'type': 2, 'id': 2009350, 'country': 'US', 'sunrise': 1668696466, 'sunset': 1668733071}, 'timezone': -28800, 'id': 5380437, 'name': 'Pacific Grove', 'cod': 200}
# Processing Record 46 of Set 1 | provideniya
# city_weather = {'coord': {'lon': -173.3, 'lat': 64.3833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}, {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 35.71, 'feels_like': 23.74, 'temp_min': 35.37, 'temp_max': 35.71, 'pressure': 1009, 'humidity': 100}, 'visibility': 2500, 'wind': {'speed': 24.61, 'deg': 170, 'gust': 38.03}, 'clouds': {'all': 100}, 'dt': 1668719590, 'sys': {'type': 1, 'id': 8875, 'country': 'RU', 'sunrise': 1668802497, 'sunset': 1668824534}, 'timezone': 43200, 'id': 4031574, 'name': 'Provideniya', 'cod': 200}
# Processing Record 47 of Set 1 | mandalgovi
# city_weather = {'coord': {'lon': 106.2708, 'lat': 45.7625}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 29.8, 'feels_like': 20.34, 'temp_min': 29.8, 'temp_max': 29.8, 'pressure': 1019, 'humidity': 33, 'sea_level': 1019, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 11.34, 'deg': 160, 'gust': 25.46}, 'clouds': {'all': 100}, 'dt': 1668719590, 'sys': {'country': 'MN', 'sunrise': 1668729497, 'sunset': 1668763319}, 'timezone': 28800, 'id': 2030065, 'name': 'Mandalgovi', 'cod': 200}
# Processing Record 48 of Set 1 | sola
# city_weather = {'coord': {'lon': 167.55, 'lat': -13.8833}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 82.36, 'feels_like': 87.13, 'temp_min': 82.36, 'temp_max': 82.36, 'pressure': 1011, 'humidity': 70, 'sea_level': 1011, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 9.57, 'deg': 51, 'gust': 9.84}, 'clouds': {'all': 16}, 'dt': 1668718835, 'sys': {'country': 'VU', 'sunrise': 1668708702, 'sunset': 1668754695}, 'timezone': 39600, 'id': 2134814, 'name': 'Sola', 'cod': 200}
# Processing Record 49 of Set 1 | asau
# city_weather = {'coord': {'lon': 26.4, 'lat': 46.4333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 32.92, 'feels_like': 32.92, 'temp_min': 32.92, 'temp_max': 33.28, 'pressure': 1003, 'humidity': 91, 'sea_level': 1003, 'grnd_level': 955}, 'visibility': 9788, 'wind': {'speed': 1.68, 'deg': 226, 'gust': 9.66}, 'clouds': {'all': 98}, 'dt': 1668719591, 'sys': {'type': 1, 'id': 6909, 'country': 'RO', 'sunrise': 1668662319, 'sunset': 1668696015}, 'timezone': 7200, 'id': 686090, 'name': 'Asău', 'cod': 200}
# Processing Record 50 of Set 1 | punta arenas
# city_weather = {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 55.51, 'feels_like': 52.83, 'temp_min': 55.11, 'temp_max': 55.51, 'pressure': 1001, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 280}, 'clouds': {'all': 40}, 'dt': 1668719548, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1668673958, 'sunset': 1668731095}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 1 of Set 2 | tuktoyaktuk
# city_weather = {'coord': {'lon': -133.0374, 'lat': 69.4541}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 17.44, 'feels_like': 4.84, 'temp_min': 17.44, 'temp_max': 17.44, 'pressure': 1030, 'humidity': 74, 'sea_level': 1030, 'grnd_level': 1030}, 'visibility': 10000, 'wind': {'speed': 12.1, 'deg': 251, 'gust': 26.8}, 'clouds': {'all': 47}, 'dt': 1668719651, 'sys': {'country': 'CA', 'sunrise': 1668710574, 'sunset': 1668724302}, 'timezone': -25200, 'id': 6170031, 'name': 'Tuktoyaktuk', 'cod': 200}
# Processing Record 2 of Set 2 | sentyabrskiy
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 3 of Set 2 | onega
# city_weather = {'coord': {'lon': 38.1404, 'lat': 63.9061}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.26, 'feels_like': 19.76, 'temp_min': 24.26, 'temp_max': 24.26, 'pressure': 1023, 'humidity': 91, 'sea_level': 1023, 'grnd_level': 1019}, 'visibility': 10000, 'wind': {'speed': 3.53, 'deg': 205, 'gust': 6.33}, 'clouds': {'all': 99}, 'dt': 1668719652, 'sys': {'country': 'RU', 'sunrise': 1668751360, 'sunset': 1668774164}, 'timezone': 10800, 'id': 515246, 'name': 'Onega', 'cod': 200}
# Processing Record 4 of Set 2 | tsihombe
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | port alfred
# city_weather = {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.18, 'feels_like': 63.61, 'temp_min': 63.18, 'temp_max': 63.18, 'pressure': 1016, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 6.64, 'deg': 125, 'gust': 7.49}, 'clouds': {'all': 100}, 'dt': 1668719652, 'sys': {'type': 2, 'id': 2072861, 'country': 'ZA', 'sunrise': 1668654026, 'sunset': 1668704073}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 6 of Set 2 | neiafu
# city_weather = {'coord': {'lon': -173.9833, 'lat': -18.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.51, 'feels_like': 79.5, 'temp_min': 78.51, 'temp_max': 78.51, 'pressure': 1013, 'humidity': 73, 'sea_level': 1013, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 4.23, 'deg': 70, 'gust': 3.87}, 'clouds': {'all': 9}, 'dt': 1668719652, 'sys': {'country': 'TO', 'sunrise': 1668790223, 'sunset': 1668837135}, 'timezone': 46800, 'id': 4032420, 'name': 'Neiafu', 'cod': 200}
# Processing Record 7 of Set 2 | longlac
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 2 | la palma
# city_weather = {'coord': {'lon': -118.0467, 'lat': 33.8464}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.1, 'feels_like': 73.98, 'temp_min': 69.33, 'temp_max': 81.5, 'pressure': 1019, 'humidity': 12}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 310}, 'clouds': {'all': 75}, 'dt': 1668719653, 'sys': {'type': 2, 'id': 2010205, 'country': 'US', 'sunrise': 1668695192, 'sunset': 1668732487}, 'timezone': -28800, 'id': 5364022, 'name': 'La Palma', 'cod': 200}
# Processing Record 9 of Set 2 | sao joao da barra
# city_weather = {'coord': {'lon': -41.0511, 'lat': -21.6403}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.29, 'feels_like': 76.05, 'temp_min': 75.29, 'temp_max': 75.29, 'pressure': 1015, 'humidity': 75, 'sea_level': 1015, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 17.2, 'deg': 187, 'gust': 26.04}, 'clouds': {'all': 52}, 'dt': 1668719653, 'sys': {'type': 1, 'id': 8337, 'country': 'BR', 'sunrise': 1668671645, 'sunset': 1668719071}, 'timezone': -10800, 'id': 3448903, 'name': 'São João da Barra', 'cod': 200}
# Processing Record 10 of Set 2 | kaitangata
# city_weather = {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 54.3, 'feels_like': 53.56, 'temp_min': 54.3, 'temp_max': 54.3, 'pressure': 1008, 'humidity': 88, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 93, 'gust': 5.66}, 'rain': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1668719454, 'sys': {'country': 'NZ', 'sunrise': 1668704125, 'sunset': 1668758170}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# Processing Record 11 of Set 2 | tikrit
# city_weather = {'coord': {'lon': 43.6782, 'lat': 34.6071}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 62.11, 'feels_like': 60.75, 'temp_min': 62.11, 'temp_max': 62.11, 'pressure': 1017, 'humidity': 58, 'sea_level': 1017, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 5.35, 'deg': 318, 'gust': 5.64}, 'clouds': {'all': 0}, 'dt': 1668719653, 'sys': {'country': 'IQ', 'sunrise': 1668742902, 'sunset': 1668779963}, 'timezone': 10800, 'id': 90150, 'name': 'Tikrit', 'cod': 200}
# Processing Record 12 of Set 2 | arraial do cabo
# city_weather = {'coord': {'lon': -42.0278, 'lat': -22.9661}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 75.06, 'feels_like': 75.51, 'temp_min': 75.06, 'temp_max': 75.06, 'pressure': 1016, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 180}, 'clouds': {'all': 40}, 'dt': 1668719365, 'sys': {'type': 1, 'id': 8326, 'country': 'BR', 'sunrise': 1668671747, 'sunset': 1668719437}, 'timezone': -10800, 'id': 3471451, 'name': 'Arraial do Cabo', 'cod': 200}
# Processing Record 13 of Set 2 | parkes
# city_weather = {'coord': {'lon': 148.1833, 'lat': -33.1333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.28, 'feels_like': 51.6, 'temp_min': 53.28, 'temp_max': 53.28, 'pressure': 1016, 'humidity': 70, 'sea_level': 1016, 'grnd_level': 972}, 'visibility': 10000, 'wind': {'speed': 3.58, 'deg': 79, 'gust': 5.66}, 'clouds': {'all': 0}, 'dt': 1668719654, 'sys': {'country': 'AU', 'sunrise': 1668711352, 'sunset': 1668761343}, 'timezone': 39600, 'id': 2153778, 'name': 'Parkes', 'cod': 200}
# Processing Record 14 of Set 2 | keti bandar
# city_weather = {'coord': {'lon': 67.4497, 'lat': 24.1447}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77.63, 'feels_like': 78.42, 'temp_min': 77.63, 'temp_max': 77.63, 'pressure': 1013, 'humidity': 71, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 8.81, 'deg': 281, 'gust': 10.8}, 'clouds': {'all': 3}, 'dt': 1668719654, 'sys': {'country': 'PK', 'sunrise': 1668736044, 'sunset': 1668775409}, 'timezone': 18000, 'id': 1174451, 'name': 'Keti Bandar', 'cod': 200}
# Processing Record 15 of Set 2 | oktyabrskiy
# city_weather = {'coord': {'lon': 53.471, 'lat': 54.4815}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 26.91, 'feels_like': 15.73, 'temp_min': 26.91, 'temp_max': 26.91, 'pressure': 1020, 'humidity': 84, 'sea_level': 1020, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 13.4, 'deg': 125, 'gust': 28.48}, 'clouds': {'all': 100}, 'dt': 1668719444, 'sys': {'country': 'RU', 'sunrise': 1668744066, 'sunset': 1668774098}, 'timezone': 18000, 'id': 515879, 'name': "Oktyabr'skiy", 'cod': 200}
# Processing Record 16 of Set 2 | airai
# city_weather = {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 61.16, 'feels_like': 61.02, 'temp_min': 61.16, 'temp_max': 61.16, 'pressure': 1010, 'humidity': 86, 'sea_level': 1010, 'grnd_level': 855}, 'visibility': 10000, 'wind': {'speed': 1.86, 'deg': 51, 'gust': 2.57}, 'clouds': {'all': 81}, 'dt': 1668719655, 'sys': {'country': 'TL', 'sunrise': 1668719251, 'sunset': 1668764377}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# Processing Record 17 of Set 2 | hobart
# city_weather = {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 50.09, 'feels_like': 48.97, 'temp_min': 48.06, 'temp_max': 50.25, 'pressure': 1013, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 310}, 'clouds': {'all': 20}, 'dt': 1668719404, 'sys': {'type': 2, 'id': 2002195, 'country': 'AU', 'sunrise': 1668710143, 'sunset': 1668762962}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# Processing Record 18 of Set 2 | afzalpur
# city_weather = {'coord': {'lon': 76.35, 'lat': 17.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.7, 'feels_like': 65.48, 'temp_min': 66.7, 'temp_max': 66.7, 'pressure': 1012, 'humidity': 51, 'sea_level': 1012, 'grnd_level': 965}, 'visibility': 10000, 'wind': {'speed': 9.46, 'deg': 65, 'gust': 12.84}, 'clouds': {'all': 0}, 'dt': 1668719655, 'sys': {'country': 'IN', 'sunrise': 1668733250, 'sunset': 1668773930}, 'timezone': 19800, 'id': 1279306, 'name': 'Afzalpur', 'cod': 200}
# Processing Record 19 of Set 2 | zhezkazgan
# city_weather = {'coord': {'lon': 67.7144, 'lat': 47.8043}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 22.08, 'feels_like': 13.03, 'temp_min': 22.08, 'temp_max': 22.08, 'pressure': 1030, 'humidity': 85, 'sea_level': 1030, 'grnd_level': 981}, 'visibility': 10000, 'wind': {'speed': 7.65, 'deg': 87, 'gust': 14.36}, 'snow': {'1h': 0.11}, 'clouds': {'all': 100}, 'dt': 1668719655, 'sys': {'country': 'KZ', 'sunrise': 1668739134, 'sunset': 1668772192}, 'timezone': 21600, 'id': 1516589, 'name': 'Zhezkazgan', 'cod': 200}
# Processing Record 20 of Set 2 | busselton
# city_weather = {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 52.07, 'feels_like': 50.83, 'temp_min': 52.07, 'temp_max': 52.07, 'pressure': 1003, 'humidity': 82, 'sea_level': 1003, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 16.2, 'deg': 215, 'gust': 26.35}, 'clouds': {'all': 100}, 'dt': 1668719656, 'sys': {'country': 'AU', 'sunrise': 1668719167, 'sunset': 1668769298}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 21 of Set 2 | chiredzi
# city_weather = {'coord': {'lon': 31.6667, 'lat': -21.05}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 78.66, 'feels_like': 78.62, 'temp_min': 78.66, 'temp_max': 78.66, 'pressure': 1011, 'humidity': 51, 'sea_level': 1011, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 5.28, 'deg': 40, 'gust': 14.47}, 'clouds': {'all': 0}, 'dt': 1668719656, 'sys': {'country': 'ZW', 'sunrise': 1668654253, 'sunset': 1668701553}, 'timezone': 7200, 'id': 893485, 'name': 'Chiredzi', 'cod': 200}
# Processing Record 22 of Set 2 | faanui
# city_weather = {'coord': {'lon': -151.75, 'lat': -16.4833}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 79.3, 'feels_like': 79.3, 'temp_min': 79.3, 'temp_max': 79.3, 'pressure': 1013, 'humidity': 75, 'sea_level': 1013, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 4.25, 'deg': 298, 'gust': 4.72}, 'rain': {'1h': 0.77}, 'clouds': {'all': 69}, 'dt': 1668719656, 'sys': {'country': 'PF', 'sunrise': 1668698699, 'sunset': 1668745160}, 'timezone': -36000, 'id': 4034551, 'name': 'Faanui', 'cod': 200}
# Processing Record 23 of Set 2 | khonuu
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 24 of Set 2 | trincomalee
# city_weather = {'coord': {'lon': 81.2335, 'lat': 8.5711}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.19, 'feels_like': 79, 'temp_min': 78.19, 'temp_max': 78.19, 'pressure': 1009, 'humidity': 70, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 10.94, 'deg': 338, 'gust': 14.25}, 'clouds': {'all': 100}, 'dt': 1668719657, 'sys': {'country': 'LK', 'sunrise': 1668731325, 'sunset': 1668773511}, 'timezone': 19800, 'id': 1226260, 'name': 'Trincomalee', 'cod': 200}
# Processing Record 25 of Set 2 | riviere-au-renard
# city_weather = {'coord': {'lon': -64.3971, 'lat': 48.9957}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 30.49, 'feels_like': 21.11, 'temp_min': 30.49, 'temp_max': 30.49, 'pressure': 997, 'humidity': 89, 'sea_level': 997, 'grnd_level': 997}, 'visibility': 3979, 'wind': {'speed': 11.5, 'deg': 307, 'gust': 16.8}, 'clouds': {'all': 100}, 'dt': 1668719657, 'sys': {'type': 1, 'id': 807, 'country': 'CA', 'sunrise': 1668684617, 'sunset': 1668717307}, 'timezone': -18000, 'id': 6943832, 'name': 'Riviere-au-Renard', 'cod': 200}
# Processing Record 26 of Set 2 | pontes e lacerda
# city_weather = {'coord': {'lon': -59.3353, 'lat': -15.2261}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 98.64, 'feels_like': 94.37, 'temp_min': 98.64, 'temp_max': 98.64, 'pressure': 1005, 'humidity': 15, 'sea_level': 1005, 'grnd_level': 978}, 'visibility': 10000, 'wind': {'speed': 6.08, 'deg': 97, 'gust': 9.08}, 'clouds': {'all': 5}, 'dt': 1668719541, 'sys': {'country': 'BR', 'sunrise': 1668676636, 'sunset': 1668722857}, 'timezone': -14400, 'id': 3453060, 'name': 'Pontes e Lacerda', 'cod': 200}
# Processing Record 27 of Set 2 | longyearbyen
# city_weather = {'coord': {'lon': 15.6401, 'lat': 78.2186}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 22.84, 'feels_like': 13.66, 'temp_min': 22.84, 'temp_max': 22.84, 'pressure': 1020, 'humidity': 80}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1668719658, 'sys': {'type': 1, 'id': 1663, 'country': 'SJ', 'sunrise': 0, 'sunset': 0}, 'timezone': 3600, 'id': 2729907, 'name': 'Longyearbyen', 'cod': 200}
# Processing Record 28 of Set 2 | ulaangom
# city_weather = {'coord': {'lon': 92.0667, 'lat': 49.9811}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 18.72, 'feels_like': 9.39, 'temp_min': 18.72, 'temp_max': 18.72, 'pressure': 1030, 'humidity': 89, 'sea_level': 1030, 'grnd_level': 915}, 'visibility': 872, 'wind': {'speed': 7.11, 'deg': 310, 'gust': 10.4}, 'snow': {'1h': 0.12}, 'clouds': {'all': 100}, 'dt': 1668719658, 'sys': {'country': 'MN', 'sunrise': 1668733721, 'sunset': 1668765914}, 'timezone': 25200, 'id': 1515029, 'name': 'Ulaangom', 'cod': 200}
# Processing Record 29 of Set 2 | narsaq
# city_weather = {'coord': {'lon': -46.05, 'lat': 60.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 23.22, 'feels_like': 16.83, 'temp_min': 23.22, 'temp_max': 23.22, 'pressure': 991, 'humidity': 81, 'sea_level': 991, 'grnd_level': 988}, 'visibility': 10000, 'wind': {'speed': 4.94, 'deg': 40, 'gust': 5.55}, 'clouds': {'all': 100}, 'dt': 1668719449, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1668683592, 'sunset': 1668709523}, 'timezone': -10800, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# Processing Record 30 of Set 2 | illoqqortoormiut
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 31 of Set 2 | kloulklubed
# city_weather = {'coord': {'lon': 134.2556, 'lat': 7.0419}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 82.63, 'feels_like': 90.37, 'temp_min': 82.63, 'temp_max': 82.63, 'pressure': 1008, 'humidity': 80, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 15.61, 'deg': 80, 'gust': 17.96}, 'clouds': {'all': 100}, 'dt': 1668719305, 'sys': {'country': 'PW', 'sunrise': 1668718467, 'sunset': 1668760914}, 'timezone': 32400, 'id': 7671223, 'name': 'Kloulklubed', 'cod': 200}
# Processing Record 32 of Set 2 | sembakung
# city_weather = {'coord': {'lon': 117.25, 'lat': 3.8167}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 73.78, 'feels_like': 75.51, 'temp_min': 73.78, 'temp_max': 73.78, 'pressure': 1007, 'humidity': 99, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 1.14, 'deg': 298, 'gust': 1.12}, 'rain': {'1h': 0.18}, 'clouds': {'all': 98}, 'dt': 1668719658, 'sys': {'country': 'ID', 'sunrise': 1668722279, 'sunset': 1668765266}, 'timezone': 28800, 'id': 1627877, 'name': 'Sembakung', 'cod': 200}
# Processing Record 33 of Set 2 | hermanus
# city_weather = {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 56.8, 'feels_like': 55.09, 'temp_min': 56.8, 'temp_max': 56.8, 'pressure': 1017, 'humidity': 62, 'sea_level': 1017, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 5.68, 'deg': 137, 'gust': 6.46}, 'clouds': {'all': 100}, 'dt': 1668719659, 'sys': {'type': 2, 'id': 2006131, 'country': 'ZA', 'sunrise': 1668655757, 'sunset': 1668706017}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 34 of Set 2 | kasongo-lunda
# city_weather = {'coord': {'lon': 16.8167, 'lat': -6.4667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.23, 'feels_like': 71.51, 'temp_min': 70.23, 'temp_max': 70.23, 'pressure': 1013, 'humidity': 97, 'sea_level': 1013, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 1.63, 'deg': 308, 'gust': 1.77}, 'clouds': {'all': 87}, 'dt': 1668719659, 'sys': {'country': 'CD', 'sunrise': 1668659120, 'sunset': 1668703815}, 'timezone': 3600, 'id': 2315026, 'name': 'Kasongo-Lunda', 'cod': 200}
# Processing Record 35 of Set 2 | naze
# ...
# Processing Record 10 of Set 16 | guanare
# city_weather = {'coord': {'lon': -69.7421, 'lat': 9.0418}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 89.62, 'feels_like': 97.7, 'temp_min': 89.62, 'temp_max': 89.62, 'pressure': 1009, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 40}, 'clouds': {'all': 91}, 'dt': 1668720658, 'sys': {'type': 1, 'id': 8725, 'country': 'VE', 'sunrise': 1668681185, 'sunset': 1668723304}, 'timezone': -14400, 'id': 3640226, 'name': 'Guanare', 'cod': 200}
# Processing Record 11 of Set 16 | paranavai
# city_weather = {'coord': {'lon': -52.4653, 'lat': -23.0731}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 72.66, 'feels_like': 71.65, 'temp_min': 72.66, 'temp_max': 72.66, 'pressure': 1012, 'humidity': 43, 'sea_level': 1012, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 142, 'gust': 7.29}, 'clouds': {'all': 0}, 'dt': 1668720658, 'sys': {'country': 'BR', 'sunrise': 1668674241, 'sunset': 1668721954}, 'timezone': -10800, 'id': 3455051, 'name': 'Paranavaí', 'cod': 200}
# Processing Record 12 of Set 16 | lebedyan
# city_weather = {'coord': {'lon': 39.1664, 'lat': 53.0194}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 24.66, 'feels_like': 14.59, 'temp_min': 24.66, 'temp_max': 24.66, 'pressure': 1004, 'humidity': 94, 'sea_level': 1004, 'grnd_level': 989}, 'visibility': 2689, 'wind': {'speed': 10.04, 'deg': 17, 'gust': 19.01}, 'clouds': {'all': 100}, 'dt': 1668720658, 'sys': {'country': 'RU', 'sunrise': 1668747127, 'sunset': 1668777904}, 'timezone': 10800, 'id': 536518, 'name': "Lebedyan'", 'cod': 200}
# Processing Record 13 of Set 16 | sulecin
# city_weather = {'coord': {'lon': 15.1168, 'lat': 52.4443}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 35.49, 'feels_like': 27.01, 'temp_min': 34.7, 'temp_max': 35.89, 'pressure': 1005, 'humidity': 71, 'sea_level': 1005, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 12.41, 'deg': 96, 'gust': 27.07}, 'clouds': {'all': 34}, 'dt': 1668720658, 'sys': {'type': 2, 'id': 2036770, 'country': 'PL', 'sunrise': 1668666260, 'sunset': 1668697491}, 'timezone': 3600, 'id': 3084237, 'name': 'Sulęcin', 'cod': 200}
# Processing Record 14 of Set 16 | huarmey
# city_weather = {'coord': {'lon': -78.1522, 'lat': -10.0681}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 68.14, 'feels_like': 68.23, 'temp_min': 68.14, 'temp_max': 68.14, 'pressure': 1011, 'humidity': 76, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 10.18, 'deg': 188, 'gust': 13.13}, 'clouds': {'all': 92}, 'dt': 1668720659, 'sys': {'country': 'PE', 'sunrise': 1668681607, 'sunset': 1668726920}, 'timezone': -18000, 'id': 3939168, 'name': 'Huarmey', 'cod': 200}
# Processing Record 15 of Set 16 | guiren
# city_weather = {'coord': {'lon': 118.1889, 'lat': 33.6697}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 54.79, 'feels_like': 53.78, 'temp_min': 54.79, 'temp_max': 54.79, 'pressure': 1023, 'humidity': 81, 'sea_level': 1023, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 8.43, 'deg': 79, 'gust': 19.17}, 'clouds': {'all': 99}, 'dt': 1668720573, 'sys': {'country': 'CN', 'sunrise': 1668724894, 'sunset': 1668762201}, 'timezone': 28800, 'id': 1809483, 'name': 'Guiren', 'cod': 200}
# Processing Record 16 of Set 16 | svetlogorsk
# city_weather = {'coord': {'lon': 29.7333, 'lat': 52.6333}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 27.14, 'feels_like': 21.25, 'temp_min': 27.14, 'temp_max': 27.14, 'pressure': 1007, 'humidity': 86, 'sea_level': 1007, 'grnd_level': 990}, 'visibility': 9141, 'wind': {'speed': 5.12, 'deg': 80, 'gust': 7.94}, 'snow': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1668720659, 'sys': {'country': 'BY', 'sunrise': 1668749299, 'sunset': 1668780261}, 'timezone': 10800, 'id': 10722858, 'name': 'Forsytheganj', 'cod': 200}
# Processing Record 17 of Set 16 | madera
# city_weather = {'coord': {'lon': -119.8343, 'lat': 37.1666}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 67.89, 'feels_like': 65.89, 'temp_min': 62.4, 'temp_max': 72.52, 'pressure': 1023, 'humidity': 32}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 295, 'gust': 7}, 'clouds': {'all': 86}, 'dt': 1668720659, 'sys': {'type': 2, 'id': 2005939, 'country': 'US', 'sunrise': 1668696037, 'sunset': 1668732500}, 'timezone': -28800, 'id': 5369578, 'name': 'Madera', 'cod': 200}
# Processing Record 18 of Set 16 | ventspils
# city_weather = {'coord': {'lon': 21.5606, 'lat': 57.3894}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 31.93, 'feels_like': 27.36, 'temp_min': 31.93, 'temp_max': 31.93, 'pressure': 1013, 'humidity': 100}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 50}, 'clouds': {'all': 20}, 'dt': 1668720659, 'sys': {'type': 1, 'id': 1877, 'country': 'LV', 'sunrise': 1668666061, 'sunset': 1668694597}, 'timezone': 7200, 'id': 454310, 'name': 'Ventspils', 'cod': 200}
# Processing Record 19 of Set 16 | dogondoutchi
# city_weather = {'coord': {'lon': 4.0287, 'lat': 13.6393}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.53, 'feels_like': 76.93, 'temp_min': 78.53, 'temp_max': 78.53, 'pressure': 1013, 'humidity': 18, 'sea_level': 1013, 'grnd_level': 987}, 'visibility': 10000, 'wind': {'speed': 6.42, 'deg': 35, 'gust': 6.82}, 'clouds': {'all': 75}, 'dt': 1668720660, 'sys': {'country': 'NE', 'sunrise': 1668663868, 'sunset': 1668705207}, 'timezone': 3600, 'id': 2445553, 'name': 'Dogondoutchi', 'cod': 200}
# Processing Record 20 of Set 16 | moranbah
# city_weather = {'coord': {'lon': 148.0466, 'lat': -22.0016}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.6, 'feels_like': 75.34, 'temp_min': 75.6, 'temp_max': 75.6, 'pressure': 1013, 'humidity': 53, 'sea_level': 1013, 'grnd_level': 983}, 'visibility': 10000, 'wind': {'speed': 13.31, 'deg': 76, 'gust': 13.82}, 'clouds': {'all': 98}, 'dt': 1668720660, 'sys': {'country': 'AU', 'sunrise': 1668712619, 'sunset': 1668760142}, 'timezone': 36000, 'id': 6533368, 'name': 'Moranbah', 'cod': 200}
# Processing Record 21 of Set 16 | vostok
# city_weather = {'coord': {'lon': 135.8833, 'lat': 46.4856}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 20.64, 'feels_like': 15.51, 'temp_min': 20.64, 'temp_max': 20.64, 'pressure': 1021, 'humidity': 81, 'sea_level': 1021, 'grnd_level': 947}, 'visibility': 10000, 'wind': {'speed': 3.6, 'deg': 124, 'gust': 4.32}, 'clouds': {'all': 100}, 'dt': 1668720660, 'sys': {'country': 'RU', 'sunrise': 1668722512, 'sunset': 1668756088}, 'timezone': 36000, 'id': 2013279, 'name': 'Vostok', 'cod': 200}
# Processing Record 22 of Set 16 | pangkalanbuun
# city_weather = {'coord': {'lon': 111.6167, 'lat': -2.6833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.78, 'feels_like': 75.47, 'temp_min': 73.78, 'temp_max': 73.78, 'pressure': 1009, 'humidity': 98, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 1.95, 'deg': 276, 'gust': 7.45}, 'clouds': {'all': 100}, 'dt': 1668720661, 'sys': {'country': 'ID', 'sunrise': 1668723090, 'sunset': 1668767160}, 'timezone': 25200, 'id': 1632694, 'name': 'Pangkalanbuun', 'cod': 200}
# Processing Record 23 of Set 16 | lenger
# city_weather = {'coord': {'lon': 69.8839, 'lat': 42.183}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 29.64, 'feels_like': 21.78, 'temp_min': 29.64, 'temp_max': 29.64, 'pressure': 1020, 'humidity': 60, 'sea_level': 1020, 'grnd_level': 929}, 'visibility': 10000, 'wind': {'speed': 8.3, 'deg': 124, 'gust': 6.46}, 'clouds': {'all': 100}, 'dt': 1668720661, 'sys': {'type': 1, 'id': 8824, 'country': 'KZ', 'sunrise': 1668737648, 'sunset': 1668772636}, 'timezone': 21600, 'id': 1521379, 'name': 'Lenger', 'cod': 200}
# Processing Record 24 of Set 16 | bahia de caraquez
# city_weather = {'coord': {'lon': -80.4167, 'lat': -0.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.38, 'feels_like': 76.37, 'temp_min': 75.38, 'temp_max': 75.38, 'pressure': 1009, 'humidity': 80, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 14.34, 'deg': 265, 'gust': 15.95}, 'clouds': {'all': 93}, 'dt': 1668720661, 'sys': {'type': 1, 'id': 8552, 'country': 'EC', 'sunrise': 1668682946, 'sunset': 1668726667}, 'timezone': -18000, 'id': 3660401, 'name': 'Bahía de Caráquez', 'cod': 200}
# Processing Record 25 of Set 16 | yanam
# city_weather = {'coord': {'lon': 82.2167, 'lat': 16.7333}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 69.35, 'feels_like': 69.69, 'temp_min': 69.35, 'temp_max': 69.35, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 1, 'gust': 10.33}, 'clouds': {'all': 98}, 'dt': 1668720662, 'sys': {'country': 'IN', 'sunrise': 1668731799, 'sunset': 1668772565}, 'timezone': 19800, 'id': 1252795, 'name': 'Yanam', 'cod': 200}
# Processing Record 26 of Set 16 | carutapera
# city_weather = {'coord': {'lon': -46.02, 'lat': -1.195}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 77.61, 'feels_like': 79.12, 'temp_min': 77.61, 'temp_max': 77.61, 'pressure': 1009, 'humidity': 86, 'sea_level': 1009, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.31, 'deg': 51, 'gust': 12.77}, 'clouds': {'all': 90}, 'dt': 1668720662, 'sys': {'country': 'BR', 'sunrise': 1668674641, 'sunset': 1668718460}, 'timezone': -10800, 'id': 3402648, 'name': 'Carutapera', 'cod': 200}
# Processing Record 27 of Set 16 | hirado
# city_weather = {'coord': {'lon': 129.5531, 'lat': 33.3597}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 60.19, 'feels_like': 59, 'temp_min': 60.19, 'temp_max': 60.19, 'pressure': 1023, 'humidity': 66, 'sea_level': 1023, 'grnd_level': 1016}, 'visibility': 10000, 'wind': {'speed': 15.99, 'deg': 57, 'gust': 17.02}, 'clouds': {'all': 9}, 'dt': 1668720662, 'sys': {'country': 'JP', 'sunrise': 1668722127, 'sunset': 1668759511}, 'timezone': 32400, 'id': 1862555, 'name': 'Hirado', 'cod': 200}
# Processing Record 28 of Set 16 | karauzyak
# city_weather = {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 29 of Set 16 | turukhansk
# city_weather = {'coord': {'lon': 87.9833, 'lat': 65.8167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -1.28, 'feels_like': -13.88, 'temp_min': -1.28, 'temp_max': -1.28, 'pressure': 1010, 'humidity': 94, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 4836, 'wind': {'speed': 22.57, 'deg': 182, 'gust': 39.06}, 'clouds': {'all': 100}, 'dt': 1668720663, 'sys': {'country': 'RU', 'sunrise': 1668740568, 'sunset': 1668761027}, 'timezone': 25200, 'id': 1488903, 'name': 'Turukhansk', 'cod': 200}
# Processing Record 30 of Set 16 | lakatoro
# city_weather = {'coord': {'lon': 167.4164, 'lat': -16.0999}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 83.64, 'feels_like': 90.01, 'temp_min': 83.64, 'temp_max': 83.64, 'pressure': 1011, 'humidity': 71, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 7.94, 'deg': 13, 'gust': 8.88}, 'clouds': {'all': 23}, 'dt': 1668720663, 'sys': {'country': 'VU', 'sunrise': 1668708534, 'sunset': 1668754928}, 'timezone': 39600, 'id': 2136697, 'name': 'Lakatoro', 'cod': 200}
# Processing Record 31 of Set 16 | rio grande
# city_weather = {'coord': {'lon': -52.0986, 'lat': -32.035}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 82.51, 'feels_like': 86.02, 'temp_min': 82.51, 'temp_max': 82.51, 'pressure': 1018, 'humidity': 64, 'sea_level': 1018, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 8.32, 'deg': 67, 'gust': 10.47}, 'clouds': {'all': 45}, 'dt': 1668720664, 'sys': {'type': 1, 'id': 8408, 'country': 'BR', 'sunrise': 1668673168, 'sunset': 1668722851}, 'timezone': -10800, 'id': 3451138, 'name': 'Rio Grande', 'cod': 200}
# Processing Record 32 of Set 16 | sao joao del rei
# city_weather = {'coord': {'lon': -44.2617, 'lat': -21.1356}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.06, 'feels_like': 65.89, 'temp_min': 66.06, 'temp_max': 66.06, 'pressure': 1015, 'humidity': 75, 'sea_level': 1015, 'grnd_level': 913}, 'visibility': 10000, 'wind': {'speed': 8.43, 'deg': 117, 'gust': 19.89}, 'clouds': {'all': 98}, 'dt': 1668720664, 'sys': {'country': 'BR', 'sunrise': 1668672465, 'sunset': 1668719792}, 'timezone': -10800, 'id': 3448879, 'name': 'São João del Rei', 'cod': 200}
# Processing Record 33 of Set 16 | zlobin
# city_weather = {'coord': {'lon': 14.6541, 'lat': 45.2924}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 47.61, 'feels_like': 43.9, 'temp_min': 45.63, 'temp_max': 48.69, 'pressure': 1002, 'humidity': 93, 'sea_level': 1002, 'grnd_level': 915}, 'visibility': 777, 'wind': {'speed': 7.9, 'deg': 189, 'gust': 20}, 'rain': {'1h': 2.3}, 'clouds': {'all': 100}, 'dt': 1668720664, 'sys': {'type': 2, 'id': 2012765, 'country': 'HR', 'sunrise': 1668664942, 'sunset': 1668699031}, 'timezone': 3600, 'id': 3191648, 'name': 'Zlobin', 'cod': 200}
# Processing Record 34 of Set 16 | bermeo
# city_weather = {'coord': {'lon': -2.7215, 'lat': 43.4209}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 56.7, 'feels_like': 55.69, 'temp_min': 54.41, 'temp_max': 57.81, 'pressure': 1010, 'humidity': 77, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 18.84, 'deg': 287, 'gust': 24.05}, 'rain': {'1h': 0.13}, 'clouds': {'all': 71}, 'dt': 1668720665, 'sys': {'type': 1, 'id': 6395, 'country': 'ES', 'sunrise': 1668668807, 'sunset': 1668703507}, 'timezone': 3600, 'id': 3128174, 'name': 'Bermeo', 'cod': 200}
# Processing Record 35 of Set 16 | alappuzha
# city_weather = {'coord': {'lon': 76.3264, 'lat': 9.49}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 78.15, 'temp_min': 77, 'temp_max': 77, 'pressure': 1009, 'humidity': 80, 'sea_level': 1009, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 1.57, 'deg': 205, 'gust': 2.28}, 'rain': {'1h': 0.42}, 'clouds': {'all': 62}, 'dt': 1668720665, 'sys': {'type': 2, 'id': 2075015, 'country': 'IN', 'sunrise': 1668732581, 'sunset': 1668774611}, 'timezone': 19800, 'id': 1278985, 'name': 'Alappuzha', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 711

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      lat       lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson  73.5069   80.5464      5.67        95         100
# 1            Tura  25.5198   90.2201     60.87        89           0
# 2         Rikitea -23.1203 -134.9692     72.16        86         100
# 3  Severo-Kurilsk  50.6789  156.1250     33.75        69         100
# 4      Chokurdakh  70.6333  147.9167    -10.41        95          99
# 5  Port Elizabeth -33.9180   25.5701     65.10        86         100
# 6           Sitka  57.0531 -135.3300     44.49        65          20
# 7            Sale  34.0389   -6.8166     65.75       100          75
# 8         Northam  51.0333   -4.2167     51.62        81          28
# 9          Pierre  44.3683 -100.3510     20.32        63         100
#
#    Windiness Country Weather Description
# 0      15.86      RU          light snow
# 1       3.89      IN           clear sky
# 2       3.24      PF          light rain
# 3      14.23      RU     overcast clouds
# 4       6.15      RU     overcast clouds
# 5       1.99      ZA     overcast clouds
# 6       4.61      US          few clouds
# 7       4.61      MA       broken clouds
# 8      20.02      GB    scattered clouds
# 9      26.46      US     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'lat', 'lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Windiness',
#        'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df.reindex(columns=["City","Country","lat","lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"])

# Recreate the DataFrame by using the new column order


# Display sample data
city_data_df.head(10)
# Out:
#              City Country      lat       lng  Max Temp  Humidity  Cloudiness  \
# 0          Dikson      RU  73.5069   80.5464      5.67        95         100
# 1            Tura      IN  25.5198   90.2201     60.87        89           0
# 2         Rikitea      PF -23.1203 -134.9692     72.16        86         100
# 3  Severo-Kurilsk      RU  50.6789  156.1250     33.75        69         100
# 4      Chokurdakh      RU  70.6333  147.9167    -10.41        95          99
# 5  Port Elizabeth      ZA -33.9180   25.5701     65.10        86         100
# 6           Sitka      US  57.0531 -135.3300     44.49        65          20
# 7            Sale      MA  34.0389   -6.8166     65.75       100          75
# 8         Northam      GB  51.0333   -4.2167     51.62        81          28
# 9          Pierre      US  44.3683 -100.3510     20.32        63         100
#
#    Wind Speed Weather Description
# 0         NaN          light snow
# 1         NaN           clear sky
# 2         NaN          light rain
# 3         NaN     overcast clouds
# 4         NaN     overcast clouds
# 5         NaN     overcast clouds
# 6         NaN          few clouds
# 7         NaN       broken clouds
# 8         NaN    scattered clouds
# 9         NaN     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# lat                    float64
# lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label="City")
